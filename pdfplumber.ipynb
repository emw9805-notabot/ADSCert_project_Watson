# %%
pip install pdfplumber
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber

# %% [markdown]
# /Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Coca-Cola_FEMSA_Green_Bond_Framework.pdf -
# /Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Marco_de_referencia_Bono_Verde_BPDC.pdf - does not conform to header and LHCol rules
# /Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Reference_Framework_Of_Green_Social_Sustainable_Bonds_of_Bogota_Capital_District.pdf
# /Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/eval_FW_rpts/Integrated-Report-2017.pdf
#
# listing customised vertical and horizontal lines defeats the purpose

# %%
pdfs = []

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Coca-Cola_FEMSA_Green_Bond_Framework.pdf') as pdf:

    page = pdf.pages[6]
    page_6_tbl = page.extract_tables()
    print(page_6_tbl)
# Out:
# [[['', 'U S E O F P R O C E E D S\nAn amount equal to the net proceeds from the sale of our Green\nBonds is expected to refinance or finance, in whole or in part,\none or more new or existing “Eligible Green Projects,” which\nare defined as investments and expenditures to be made by\nus after the issuance date of our Green Bonds or made by us\nin the 24 months prior to such date, in eligible Green Projects\nas defined in and aligned with the four core components of the\nGBP, which recommend transparency and disclosure and pro-\nmote integrity with respect to “sustainable” bonds. We expect\nthat each of our Eligible Green Projects meets or will meet one\nor more of the eligibility criteria described below.\nWe aim for our Green Bonds to support Coca-Cola FEMSA’s\ninput to the achievement of the United Nations Sustainable\nDevelopment Goals (SDG) noted below.\nWe have identified Eligible Green Projects in three main cat-\negories. These projects are in service of our carbon footprint\n
# ...

# %%
im = page.to_image()
#im.debug_tablefinder(table_settings={})
im.show()

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Coca-Cola_FEMSA_Green_Bond_Framework.pdf') as pdf:

    page = pdf.pages[7]
    page_7_tbl = page.extract_tables(table_settings={'vertical_strategy': 'text', 'horizontal_strategy': 'text'} )
    print(page_7_tbl)
# Out:
# [[['BP Eligible Project Category E', 'ligibility Criteria', 'and Examp', 'le', 'Projects', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', 'Expenditures rela', 'ted to procur', 'em', 'ent and usage', 'of climate chang', 'e module softw', 'are', 'that'], ['', '', '', '', '', '', '', '', ''], ['Climate Change Adaptation', 'will allow us to ac', 'curately mea', 'su', 're our carbon f', 'ootprint in a syst', 'ematized mann', 'er a', 'nd track'], ['', '', '', '', '', '', '', '', ''], ['', 'progress against', 'our science-b', 'as', 'ed targets.', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', 'Expenditures rela', 'ted to our ow', 'n-', 'and third-party', 'transportation fl', 'eet such as:', '', ''], ['', '', '', '', '', '', '', '', ''], ['Clean and Mass', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['', '• Fully electric tr', 'ucks and util', 'ity', 'vehicles.', '', '', '', ''], ['', '', '', '', '', '', '', '', ''], ['Transportation', '',
# ...

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/Coca-Cola_FEMSA_Green_Bond_Framework.pdf') as pdf:

    page = pdf.pages[7]
    page_7_tbl = page.extract_tables(table_settings={'vertical_strategy': 'lines_strict', 'horizontal_strategy': 'lines_strict'} )
    print(page_7_tbl)
# Out:
# []

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/eval_FW_rpts/Integrated-Report-2017.pdf') as pdf:

    page = pdf.pages[42]
    page_42_tbl = page.extract_tables()
    print(page_42_tbl)
# Out:
# []

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/eval_FW_rpts/Integrated-Report-2017.pdf') as pdf:

    page = pdf.pages[42]
    page_42_tbl = page.extract_tables(table_settings={'vertical_strategy': 'text', 'horizontal_strategy': 'text'} )
    print(page_42_tbl)
# Out:
# [[['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '05'], ['TED REP', 'ORT 2017', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'CORPORATE PURPOSE: TO', 'CONSERVE'], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['C M', 'P C : T H', 'E F I R', 'S T C O M', 'P', 'A N Y I N', 'C', 'H I L E', '', '', '', 'E N V I R', 'O N M E N T', 'A L', 'B E', 'N E F I T S', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['T O', 'I S S U E', 'A G R', 'E E N B O', 'N', 'D', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', 'Thanks to th', 'e issue of the G', 'reen Bon', 'd, C', 'MPC has been able to finance', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', 'sustainable', 'projects in the a', 'bovemen', 'tione', 'd categories 
# ...

# %%
im = page.to_image()
im.debug_tablefinder(table_settings={})
im.show()

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/eval_FW_rpts/Integrated-Report-2017.pdf') as pdf:

    page = pdf.pages[42]
    page_42_tbl = page.extract_tables(table_settings={'vertical_strategy': 'lines_strict', 'horizontal_strategy': 'lines_strict'})
    print(page_42_tbl)
# Out:
# []

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/AES-Green-Financing-Framework-Reporting-May-2025.pdf') as pdf:

    page = pdf.pages[1]
    page_1_tbl = page.extract_tables()
    print(page_1_tbl[3])
# Out:
# [['Technology', None, None, '', 'Allocation', '', '', '% of Total Net', ''], [None, 'Technology', None, None, '($M)', None, None, 'Proceeds', None], ['', 'Renewable Energy', '', '$887.6 100.0%', None, None, None, None, None], ['', 'Remaining to be Allocated', '', '$ - 0.0%', None, None, None, None, None]]

# %%
im = page.to_image()
im.debug_tablefinder(table_settings={})
im.show()

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/AES-Green-Financing-Framework-Reporting-May-2025.pdf') as pdf:

    page = pdf.pages[1]
    page_1_tbl = page.extract_tables(table_settings={'vertical_strategy': 'text', 'horizontal_strategy': 'text'} )
    print(page_1_tbl[-1])
# Out:
# [['Green Framework Reporting', '', '', ''], ['', '', '', ''], ['May 27, 2025', '', '', ''], ['', '', '', ''], ['In May 2023, The AES Corporation (“AES”) launched an unsecured investment grade bo', 'nd', 'issuance (the', '“green'], ['bonds”). The green bonds were issued under AES’ 2020 Green Financing Framework, a', 'set', 'of guidelines', 'and'], ['commitments for AES’ green financing activities that are consistent with the Green Bond', 'Pri', 'nciples 2018', 'as'], ['published by the International Capital Markets Association.', '', '', ''], ['', '', '', ''], ['As of March 31, 2025, the full amount of the $887.6 million in net proceeds raised by the', 'iss', 'uance of the', 'May'], ['2023 green bond, $900 million 5.45% senior notes due 2028 issued by AES, has been al', 'loc', 'ated to suppo', 'rt'], ['investments in renewable energy, used to reduce emissions and accelerate the adoption', 'of', 'renewables.', 'AES,'], ['along with its subsidiaries and affiliates, directly invested in 
# ...

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/AES-Green-Financing-Framework-Reporting-May-2025.pdf') as pdf:

    page = pdf.pages[0]
    page_0_tbl = page.extract_tables(table_settings={'vertical_strategy': 'lines_strict', 'horizontal_strategy': 'lines_strict'} )
    print(page_0_tbl)
# Out:
# []

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/Marco_de_referencia_Bono_Verde_BPDC.pdf') as pdf:

    page = pdf.pages[4]
    text = page.extract_words()
    print(text)
# Out:
# [{'text': 'La', 'x0': 85.104, 'x1': 96.7512, 'top': 72.48464000000001, 'doctop': 3240.48464, 'bottom': 83.52463999999998, 'upright': True, 'height': 11.039999999999964, 'width': 11.647199999999998, 'direction': 'ltr'}, {'text': 'ISO', 'x0': 100.21776, 'x1': 117.92591999999999, 'top': 72.48464000000001, 'doctop': 3240.48464, 'bottom': 83.52463999999998, 'upright': True, 'height': 11.039999999999964, 'width': 17.708159999999992, 'direction': 'ltr'}, {'text': '26000', 'x0': 121.32624, 'x1': 148.92623999999998, 'top': 72.48464000000001, 'doctop': 3240.48464, 'bottom': 83.52463999999998, 'upright': True, 'height': 11.039999999999964, 'width': 27.59999999999998, 'direction': 'ltr'}, {'text': 'nace', 'x0': 152.27135999999996, 'x1': 172.39727999999994, 'top': 72.48464000000001, 'doctop': 3240.48464, 'bottom': 83.52463999999998, 'upright': True, 'height': 11.039999999999964, 'width': 20.12591999999998, 'direction': 'ltr'}, {'text': 'para', 'x0': 175.77551999999997, 'x1': 194.70911999999996, '
# ...

# %%
im = page.to_image()

im.show()

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/Reference_Framework_Of_Green_Social_Sustainable_Bonds_of_Bogota_Capital_District.pdf') as pdf:

    page = pdf.pages[19]
    page_17_tbl = page.extract_tables()
    print(page_17_tbl)
# Out:
# [[['Description'], ['Green\nTaxonomy of\nColombia'], ['Benefits']], [['Eligible\nGreen\nCategory'], ['Description']]]

# %%
im = page.to_image()
im.debug_tablefinder(table_settings={})
im.show()

# %%
with pdfplumber.open('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF_fails/Reference_Framework_Of_Green_Social_Sustainable_Bonds_of_Bogota_Capital_District.pdf') as pdf:

    page = pdf.pages[18]
    page_17_tbl = page.extract_tables(table_settings={'vertical_strategy': 'text', 'horizontal_strategy': 'text'})
    print(page_17_tbl)
# Out:
# [[['34', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '35'], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['The R', 'efere', 'nce Framework is', 'a set', 'of technical gui', 'de', 'lines and cri', 'teria on t', 'rans', 'parency and disclos', 'ure, based on internatio', 'nal best', 'prac-', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['tices,', 'whic', 'h promote market', 'integ', 'rity and facilitat', 'e', 'the monitori', 'ng of res', 'ourc', 'es for sustainable p', 'rojects and the underst', 'anding o', 'f their', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['estim', 'ated', 'impact. Through th', 'is Fr', 'amework, the D', 'is', 'trict Finance', 'Secretari', 'at of', 'Bogota D.C. can is', 'sue three types of bond', 's:', '', '', '', '', '', '', '', '', ''], ['', ''
# ...
