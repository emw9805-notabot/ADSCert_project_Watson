# %%
# import libraries

import pymupdf
import spacy
import re
import pandas as pd
import numpy as np
#import unicodedata
import os
from pathlib import Path
from translate import Translator

# %%
# !python3 -m spacy download es_core_news_lg
# Out:
# Collecting es-core-news-lg==3.8.0
#   Downloading es_core_news_lg-3.8.0-py3-none-any.whl (568.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.0/568.0 MB 4.2 MB/s  0:02:080:00:0100:04
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_lg')

# %%
# nlp piplines from spacy for the 3 languages. large chosen for the higher dimension word vector libraries

nlp_en = spacy.load('en_core_web_lg')
nlp_pt = spacy.load('pt_core_news_lg')
nlp_es = spacy.load('es_core_news_lg')

# %%
# lists of green bond category words for usse in spacy similarity method 

not_re_cat_words_en = ['efficiency', 'retrofit', 'pollution', 'waste', 'land', 'agriculture', 'forestry', 'forest', 
                      'fisheries', 'food', 'terrestrial', 'aquatic', 'biodiversity', 'conservation', 'transportation', 
                      'electric', 'battery', 'EV', 'charger', 'bus', 'rail', 'train', 'car', 'vehicle', 'bicycle', 
                      'non-motorized', 'aviation', 'water', 'potable', 'wastewater', 'sanitation', 'treatment', 
                      'adaptation', 'disaster', 'circular', 'recycle', 'reuse','buildings', 'appliances', 'housing']

all_cat_words_en = ['renewable', 'solar', 'wind', 'bioenergy', 'biofuel', 'biomass', 'hydropower', 'hydrogen', 
                     'hydroelectric', 'power', 'grid', 'transmission', 'generation', 'efficiency', 'retrofit', 'pollution',
                    'waste', 'land', 'agriculture', 'forestry', 'forest', 'fisheries', 'food', 'terrestrial', 'aquatic',
                    'biodiversity', 'conservation', 'transportation', 'electric', 'battery', 'EV', 'charger', 'bus',
                    'rail', 'train', 'car', 'vehicle', 'bicycle', 'non-motorized', 'aviation', 'water', 'potable',
                    'wastewater', 'sanitation', 'treatment', 'adaptation', 'disaster', 'circular', 'recycle',
                    'reuse','buildings', 'appliances', 'housing']

renewable_energy_en = ['renewable', 'solar', 'wind', 'bioenergy', 'biofuel', 'biomass', 'hydropower', 'hydrogen', 'hydroelectric', 'power', 'grid', 'transmission', 'generation']
energy_efficiency_en = ['efficiency', 'retrofit']
pollution_prevention_and_control_en = ['pollution', 'waste']
environmentally_sustainable_management_of_living_natural_resources_and_land_use_en = ['land', 'agriculture', 'forestry', 'forest', 'fisheries', 'food']
terrestrial_and_aquatic_biodiversity_conservation_en = ['terrestrial', 'aquatic', 'biodiversity', 'conservation']
clean_transportation_en = ['transportation', 'electric', 'battery', 'EV', 'charger', 'bus', 'rail', 'train', 'car', 'vehicle', 'bicycle', 'non-motorized', 'aviation']
sustainable_water_and_wastewater_management_en = ['water', 'potable', 'wastewater', 'sanitation', 'treatment']
climate_change_adaptation_en = ['adaptation', 'disaster']
circular_economy_and_or_ecoefficient_projects_en = ['circular', 'recycle', 'reuse']
green_buildings_en = ['buildings', 'appliances', 'housing']

# %%
# iterate each word in the lists through the Translator from translate - English to Portuguese

not_re_cat_words_pt = []
all_cat_words_pt = []
renewable_energy_pt = []
energy_efficiency_pt = []
pollution_prevention_and_control_pt = []
environmentally_sustainable_management_of_living_natural_resources_and_land_use_pt = []
terrestrial_and_aquatic_biodiversity_conservation_pt = []
clean_transportation_pt = []
sustainable_water_and_wastewater_management_pt = []
climate_change_adaptation_pt = []
circular_economy_and_or_ecoefficient_projects_pt = []
green_buildings_pt = []


translator = Translator(to_lang='pt',from_lang='en')
# for word in not_re_cat_words_en:
    # translation = translator.translate(word)
    # not_re_cat_words_pt.append(translation)
for word in all_cat_words_en:
    translation = translator.translate(word)
    all_cat_words_pt.append(translation)
for word in renewable_energy_en:
    translation = translator.translate(word)
    renewable_energy_pt.append(translation)
for word in energy_efficiency_en:
    translation = translator.translate(word)
    energy_efficiency_pt.append(translation)
for word in pollution_prevention_and_control_en:
    translation = translator.translate(word)
    pollution_prevention_and_control_pt.append(translation)
for word in environmentally_sustainable_management_of_living_natural_resources_and_land_use_en:
    translation = translator.translate(word)
    environmentally_sustainable_management_of_living_natural_resources_and_land_use_pt.append(translation)
for word in terrestrial_and_aquatic_biodiversity_conservation_en:
    translation = translator.translate(word)
    terrestrial_and_aquatic_biodiversity_conservation_pt.append(translation)
for word in clean_transportation_en:
    translation = translator.translate(word)
    clean_transportation_pt.append(translation)
for word in sustainable_water_and_wastewater_management_en:
    translation = translator.translate(word)
    sustainable_water_and_wastewater_management_pt.append(translation)
for word in climate_change_adaptation_en:
    translation = translator.translate(word)
    climate_change_adaptation_pt.append(translation)
for word in circular_economy_and_or_ecoefficient_projects_en:
    translation = translator.translate(word)
    circular_economy_and_or_ecoefficient_projects_pt.append(translation)
for word in green_buildings_en:
    translation = translator.translate(word)
    green_buildings_pt.append(translation)

# %%
# iterate each word in the lists through the Translator from translate - English to Spanish

not_re_cat_words_es = []
all_cat_words_es = []
renewable_energy_es = []
energy_efficiency_es = []
pollution_prevention_and_control_es = []
environmentally_sustainable_management_of_living_natural_resources_and_land_use_es = []
terrestrial_and_aquatic_biodiversity_conservation_es = []
clean_transportation_es = []
sustainable_water_and_wastewater_management_es = []
climate_change_adaptation_es = []
circular_economy_and_or_ecoefficient_projects_es = []
green_buildings_es = []


translator = Translator(to_lang='es',from_lang='en')
# for word in not_re_cat_words_en:
    # translation = translator.translate(word)
    # not_re_cat_words_es.append(translation)
for word in all_cat_words_en:
    translation = translator.translate(word)
    all_cat_words_es.append(translation)
for word in renewable_energy_en:
    translation = translator.translate(word)
    renewable_energy_es.append(translation)
for word in energy_efficiency_en:
    translation = translator.translate(word)
    energy_efficiency_es.append(translation)
for word in pollution_prevention_and_control_en:
    translation = translator.translate(word)
    pollution_prevention_and_control_es.append(translation)
for word in environmentally_sustainable_management_of_living_natural_resources_and_land_use_en:
    translation = translator.translate(word)
    environmentally_sustainable_management_of_living_natural_resources_and_land_use_es.append(translation)
for word in terrestrial_and_aquatic_biodiversity_conservation_en:
    translation = translator.translate(word)
    terrestrial_and_aquatic_biodiversity_conservation_es.append(translation)
for word in clean_transportation_en:
    translation = translator.translate(word)
    clean_transportation_es.append(translation)
for word in sustainable_water_and_wastewater_management_en:
    translation = translator.translate(word)
    sustainable_water_and_wastewater_management_es.append(translation)
for word in climate_change_adaptation_en:
    translation = translator.translate(word)
    climate_change_adaptation_es.append(translation)
for word in circular_economy_and_or_ecoefficient_projects_en:
    translation = translator.translate(word)
    circular_economy_and_or_ecoefficient_projects_es.append(translation)
for word in green_buildings_en:
    translation = translator.translate(word)
    green_buildings_es.append(translation)

# %%
# find tables in the document and return table info
# pdfname: https://www.geeksforgeeks.org/python/get-filename-from-path-without-extension-using-python/

def catTable(document, tableStrategy):
    
    pdf = pymupdf.open(document) 
    filename = os.path.basename(document)
    pdfname = filename.split('.',1)[0]

    tableCount = 0
    tablePages = []
    tableHeaders = []
    tableDFs = []


    for page_idx in range(len(pdf)): 
        page = pdf[page_idx]

        find_tables = page.find_tables(strategy = tableStrategy)
        if find_tables.tables:
            table_count = len(find_tables.tables)
            tableheader = find_tables[0].header.names # assume only 1 table per page
            tableDF = find_tables[0].to_pandas()
            tableCount += table_count
            tablePages.append(page_idx)
            tableHeaders.append(tableheader)
            tableDFs.append(tableDF)

    return filename, pdfname, tableCount, tablePages, tableHeaders, tableDFs

# %%
# assess the tables found in the catTable function to identify the Category tables and extract unique list of category phrases

def tableAssess(language, tableCount, tablePages, tableHeaders, tableDFs):

    if language == 'PT':
        keywordsCAT = ['Categoria']
        nlp = nlp_pt
    elif language == 'ES':
        keywordsCAT = ['Categoría', 'Categorías']
        nlp = nlp_es
    elif language == 'EN':
        keywordsCAT = ['Category', 'Categories', 'Criteria', 'Criterion']
        nlp = nlp_en
    
    tablePageCurrent = 0
    tablePagePrior = 0
    tablepageCurrentTrue = 0
    uniqueCats = []
    uniqueCatsNoDupes = []
    table_idx = []

    if tableCount == 1: # applicable if only 1 table detected in whole pdf
        dataFrame = tableDFs[0]
        header = tableHeaders[0]
        for keyword in keywordsCAT:
            if keyword.lower() in header[0].lower(): # assumes category col is always the first (LHS) col
                colName = header[0]
                uniqueC = dataFrame[colName].dropna().unique().tolist()
                for messyCat in uniqueC:
                    if messyCat:
                        tidyCat = messyCat.replace('\n',' ').lower()
                        uniqueCatsNoDupes.append(tidyCat)
                        table_idx.append(0)
    elif tableCount > 1:
        for idx in range(len(tableDFs)): # count of tableHeaders and DFs should be the same, based on the page level find_tables object
            tablePageCurrent = tablePages[idx]
            dataFrame = tableDFs[idx]
            header = tableHeaders[idx]
            for keyword in keywordsCAT:
                if keyword.lower() in header[0].lower():
                    colName = header[0]
                    uniqueC = dataFrame[colName].dropna().unique().tolist() # unique list of phrases in left hand col of table
                    tablepageCurrentTrue = tablePageCurrent
                    for messyCat in uniqueC:
                        if messyCat:
                            tidyCat = messyCat.replace('\n',' ').lower()
                            uniqueCats.append(tidyCat)
                            table_idx.append(idx)
                elif header[0] == 'Col0' and tablePageCurrent - tablepageCurrentTrue == 1: # the condition where the last keyword-compliant table processed was one page before the current table 
                    uniqueC = dataFrame['Col0'].dropna().unique().tolist()
                    if uniqueC:
                        for messyCat in uniqueC:
                            if messyCat:
                                tidyCat = messyCat.replace('\n',' ').lower()
                                uniqueCats.append(tidyCat)
                                table_idx.append(idx)
            tablePagePrior = tablePageCurrent
        uniqueCatsNoDupes = list(set(uniqueCats))

    return uniqueCatsNoDupes, table_idx

# %%
# clean up spurious table content and assess presence of enerygy systems

def tableClean(language, uniqueCatsNoDupes):

    sim_th_en = 0.80
    sim_th_pt = 0.80
    sim_th_es = 0.80
    cleanup_TH_en = 0.65
    cleanup_TH_pt = 0.65
    cleanup_TH_es = 0.65

    if language == 'PT':
        re = renewable_energy_pt
        not_re = not_re_cat_words_pt
        all = all_cat_words_pt
        nlp = nlp_pt
        cleanup_TH = cleanup_TH_pt
        similarity_threshold = sim_th_pt
    elif language == 'ES':
        re = renewable_energy_es
        not_re = not_re_cat_words_es
        all = all_cat_words_es
        nlp = nlp_es
        cleanup_TH = cleanup_TH_es
        similarity_threshold = sim_th_es
    elif language == 'EN':
        re = renewable_energy_en
        not_re = not_re_cat_words_en
        all = all_cat_words_en
        nlp = nlp_en
        cleanup_TH = cleanup_TH_en
        similarity_threshold = sim_th_en

    CatwordsFinal = []
    simScores_clnV6 = {}
    notresimScores = {}
    resimScoresV6 = {}
    energy_system_tbl = ""

    if len(uniqueCatsNoDupes) > 0:
        for cat in uniqueCatsNoDupes: # phrases from tables' left hand cols
            docCat = nlp(cat) # run phrase through nlp pipeline
            for wordx in all:
                docx = nlp(wordx)
                simScore_cln = docCat.similarity(docx) # compare each cat phrase to all ref words
                if simScore_cln >= cleanup_TH: 
                    CatwordsFinal.append(cat)
                    simScores_cln[cat + ' ' + wordx] = simScore_cln
                    dfsimScores_cln = pd.DataFrame.from_dict(simScores_cln, 'index')
                    CatwordsFFinal = list(set(CatwordsFinal))
        for phrase in CatwordsFFinal: # only phrases that pass the cleanup TH
            docPhrase = nlp(phrase)
            for wordy in docPhrase:
                if wordy.has_vector:
                    for worda in re:
                        doca = nlp(worda)
                        resimScore = wordy.similarity(doca) # compare each word (token) in each cat phrase to renewable energy ref words
                        if resimScore >= similarity_threshold:
                            resimScores[worda] = resimScore
                            dfresimScores = pd.DataFrame.from_dict(resimScores, 'index')
        if resimScores:                     
            energy_system_tbl = True
        else:
            energy_system_tbl = False
            dfresimScores = pd.DataFrame()
    else:
        CatwordsFFinal = []
        dfsimScores_cln = pd.DataFrame()
        dfresimScores = pd.DataFrame()

    return CatwordsFFinal, dfsimScores_cln, simScores_cln, dfresimScores, resimScores, energy_system_tbl, cleanup_TH_en, cleanup_TH_es, cleanup_TH_pt

# %%
# to find the Use of Proceeds portion of the document, returns font info for key phrases that typically indicate the start and end of that portion

def fontInfo(language, document):

    results_UOP = []
    results_SEEGP = []
    
    pdf = pymupdf.open(document)
    
    if language == 'PT':
        keywordsUOP = ['Usos dos Recursos', 'Uso de Recursos']
        keywordsSEEGP = ['Selection and Evaluation', 'Process for the Project Evaluation and Selection', 'Project Evaluation and Selection Process', 'Project Selection and Evaluation Process', 'Process for Project Evaluation and Selection', 'Project Selection and Assessment Process', 'Project Selection Criteria', 'Project evaluation & selection', 'Project Selection Process']
        keywordsSEEGP_test = ['Avaliação e Seleção de Ativos', 'Processo de Avaliação e Seleção de Projetos']
    elif language == 'ES':
        keywordsUOP = ['Uso de los Fondos', 'Uso de Fondos', 'Uso de Recursos', 'Destinos de Fondos', 'Uso de los Recursos']
        keywordsSEEGP_test = ['Proceso de Evaluación y Selección de Proyectos', 'Selección y Evaluación de Proyectos', 'Procedimiento Selección', 'Evaluación y selección de proyectos']
    elif language == 'EN':
        keywordsUOP = ['Use of Proceeds', 'Use of Funds', 'Use of the Proceeds']
        keywordsSEEGP = ['Selection and Evaluation', 'Process for the Project Evaluation and Selection', 'Project Evaluation and Selection Process', 'Project Selection and Evaluation Process', 'Process for Project Evaluation and Selection', 'Project Selection and Assessment Process', 'Project Selection Criteria', 'Project evaluation & selection', 'Project Selection Process']
        keywordsSEEGP_test = ['Selection and Evaluation', 'Process for', 'Evaluation and Selection', 'Project Evaluation', 'Assessment Process', 'Selection process', 'Project selection criteria']


    for page_idx in range(len(pdf)): 
        page = pdf[page_idx]
        dict = page.get_text("dict")
        blocks = dict["blocks"] 
        for block in blocks:
            if "lines" in block.keys():
                spans = block['lines']
                for span in spans:
                    data = span['spans']
                    for lines in data:
                        for keyword in keywordsUOP:
                            if keyword.lower() in lines['text'].lower().strip():
                                results_UOP.append((lines['text'], lines['size'], lines['bbox'], page_idx))
                        for keyword in keywordsSEEGP_test:
                            if keyword.lower() in lines['text'].lower().strip():
                                results_SEEGP.append((lines['text'], lines['size'], lines['bbox'], page_idx))

                            

    return results_UOP, results_SEEGP

# %%
# from the results of the previous function, returns the result index containing the highest font size, assuming this is a section header 

def find_max_font(results_UOP, results_SEEGP):
    
    max_font_size_UOP = 0
    for result_idx_UOP in range(len(results_UOP)):
        resultA = results_UOP[result_idx_UOP]
        if resultA[1] > max_font_size_UOP:
            max_font_size_UOP = resultA[1]
            max_idx_UOP = result_idx_UOP

    max_font_size_SEEGP = 0
    if len(results_SEEGP) == 0:
        max_idx_SEEGP = 0
    else:       
        for result_idx_SEEGP in range(len(results_SEEGP)):
            resultB = results_SEEGP[result_idx_SEEGP]
            if resultB[1] > max_font_size_SEEGP:
                max_font_size_SEEGP = resultB[1]
                max_idx_SEEGP = result_idx_SEEGP

    return max_idx_UOP, max_idx_SEEGP

# %%
# corrects the UOP portion in the cases where the functions above have returned the table of contents instances of the start and end key phrases 

def tocCheck(results_UOP, results_SEEGP, max_idx_UOP, max_idx_SEEGP):
    
    if len(results_SEEGP) == 0:
        areaUOP = results_UOP[max_idx_UOP]
        areaUOP_page = areaUOP[3]
        areaUOP_coords = areaUOP[2]
        areaUOP_y1 = areaUOP_coords[3]
        areaSEEGP_page = 0
        areaSEEGP_y0 = 0

    else:
        areaUOP = results_UOP[max_idx_UOP]
        areaSEEGP = results_SEEGP[max_idx_SEEGP]
        areaUOP_page = areaUOP[3]
        areaSEEGP_page = areaSEEGP[3]
        areaUOP_coords = areaUOP[2]
        areaSEEGP_coords = areaSEEGP[2]
        areaUOP_y1 = areaUOP_coords[3]
        areaSEEGP_y0 = areaSEEGP_coords[1]

        if areaUOP_page == areaSEEGP_page:
            if 0 < areaSEEGP_y0 - areaUOP_y1 < 40:
                results_UOP_remove = results_UOP.pop(max_idx_UOP)
                results_SEEGP_remove = results_SEEGP.pop(max_idx_SEEGP)

                max_idx_UOP, max_idx_SEEGP = find_max_font(results_UOP, results_SEEGP)

                areaUOP = results_UOP[max_idx_UOP]
                areaSEEGP = results_SEEGP[max_idx_SEEGP]
                areaUOP_page = areaUOP[3]
                areaSEEGP_page = areaSEEGP[3]
                areaUOP_coords = areaUOP[2]
                areaSEEGP_coords = areaSEEGP[2]
                areaUOP_y1 = areaUOP_coords[3]
                areaSEEGP_y0 = areaSEEGP_coords[1]

    return areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0

# %%
# discards the UOP end boundary in cases where it comes before the start boundary

def keepSEEGP(areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0):

    if areaSEEGP_page == areaUOP_page:
        if areaSEEGP_y0 < areaUOP_y1:
            keep_areaSEEGP = False
        elif areaSEEGP_y0 > areaUOP_y1:
            keep_areaSEEGP = True
    elif areaSEEGP_page > areaUOP_page:
        keep_areaSEEGP = True
    elif areaSEEGP_page < areaUOP_page:
        keep_areaSEEGP = False

    return keep_areaSEEGP

# %%
# page scenarios and extract words when keep_areaSEEGP = True
# function called by another function

def wordsUOP_endPage(document, areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0):

    pdf = pymupdf.open(document)
    extractUOPwords = []

    # iterate pages
    for page_idx in range(len(pdf)):
        page = pdf[page_idx]

       
# process four page scenarios and extract text as words
    # A: UOP all on a single page
        if page_idx == areaUOP_page and page_idx == areaSEEGP_page:
            for word in page.get_text('words'):
                x0, y0, x1, y1, messyText, *_ = word
                if y0 > areaUOP_y1 and y1 < areaSEEGP_y0:
                    tidyText = messyText.replace('\n',' ').lower()
                    extractUOPwords.append(tidyText)

    # UOP across >1 page
    # B: current page is start page
        elif page_idx == areaUOP_page:
            for word in page.get_text('words'):
                x0, y0, x1, y1, messyText, *_ = word
                if y0 > areaUOP_y1:
                    tidyText = messyText.replace('\n',' ').lower()
                    extractUOPwords.append(tidyText)

    # D: current page is neither start nor end page but is in the UOP area
        elif page_idx > areaUOP_page and page_idx < areaSEEGP_page:
            for word in page.get_text('words'):
                x0, y0, x1, y1, messyText, *_ = word
                tidyText = messyText.replace('\n',' ').lower()
                extractUOPwords.append(tidyText)

    # C: current page is end page
        elif page_idx == areaSEEGP_page:
                for word in page.get_text('words'):
                    x0, y0, x1, y1, messyText, *_ = word
                    if y1 < areaSEEGP_y0:
                        tidyText = messyText.replace('\n',' ').lower()
                        extractUOPwords.append(tidyText)

    return extractUOPwords

# %%
# iterate pages in the pdf and extract words, preferrably between the UOP and SEEGP sections or else from UOP to end

def wordsUOP(keep_areaSEEGP, document, areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0):
    # language = language

    pdf = pymupdf.open(document)

    if keep_areaSEEGP == True:
        extractUOPwords = wordsUOP_endPage(document, areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0)
        UOPwordsNoDupes = list(set(extractUOPwords))

    elif keep_areaSEEGP == False:
        extractUOPwords = []

# iterate pages
        for page_idx in range(len(pdf)):
            page = pdf[page_idx]
       
    # process two page scenarios and extract text as words

        # assume UOP across > 1 page
        # B: current page is start page
            if page_idx == areaUOP_page:
                for word in page.get_text('words'):
                    x0, y0, x1, y1, messyText, *_ = word
                    if y0 > areaUOP_y1:
                        tidyText = messyText.replace('\n',' ').lower()
                        extractUOPwords.append(tidyText)

        # E: current page is after the UOP start page
            elif page_idx > areaUOP_page:
                for word in page.get_text('words'):
                    x0, y0, x1, y1, messyText, *_ = word
                    tidyText = messyText.replace('\n',' ').lower()
                    extractUOPwords.append(tidyText)
    
        UOPwordsNoDupes = list(set(extractUOPwords))
    
    return UOPwordsNoDupes

# %%
# process words into category word dictionaries where doc.similarity score passes threshold

def UOPwords_to_Catwords(language, UOPwordsNoDupes):

    sim_th_en = 0.80
    sim_th_pt = 0.80
    sim_th_es = 0.80

    if language == 'EN':
        nlp = nlp_en
        re = renewable_energy_en
        ee = energy_efficiency_en
        ppc = pollution_prevention_and_control_en
        esml = environmentally_sustainable_management_of_living_natural_resources_and_land_use_en
        tabc = terrestrial_and_aquatic_biodiversity_conservation_en
        ct = clean_transportation_en
        swwm = sustainable_water_and_wastewater_management_en
        cca = climate_change_adaptation_en
        ce = circular_economy_and_or_ecoefficient_projects_en
        gb = green_buildings_en
        similarity_threshold = sim_th_en
    elif language == 'PT':
        nlp = nlp_pt
        re = renewable_energy_pt
        ee = energy_efficiency_pt
        ppc = pollution_prevention_and_control_pt
        esml = environmentally_sustainable_management_of_living_natural_resources_and_land_use_pt
        tabc = terrestrial_and_aquatic_biodiversity_conservation_pt
        ct = clean_transportation_pt
        swwm = sustainable_water_and_wastewater_management_pt
        cca = climate_change_adaptation_pt
        ce = circular_economy_and_or_ecoefficient_projects_pt
        gb = green_buildings_pt
        similarity_threshold = sim_th_pt
    elif language == 'ES':
        nlp = nlp_es
        re = renewable_energy_es
        ee = energy_efficiency_es
        ppc = pollution_prevention_and_control_es
        esml = environmentally_sustainable_management_of_living_natural_resources_and_land_use_es
        tabc = terrestrial_and_aquatic_biodiversity_conservation_es
        ct = clean_transportation_es
        swwm = sustainable_water_and_wastewater_management_es
        cca = climate_change_adaptation_es
        ce = circular_economy_and_or_ecoefficient_projects_es
        gb = green_buildings_es
        similarity_threshold = sim_th_es

    # outputs
    simsre = {}
    energy_system_uop = ""
    simsee = {}
    simsppc = {}
    simsesml = {}
    simstabc = {}
    simsct = {}
    simsswwm = {}
    simscca = {}
    simsce = {}
    simsgb = {}
    cat_count_uop = 0
    

    for wordb in UOPwordsNoDupes:
        docb = nlp(wordb)
        for token in docb: # expect each docb has only 1 token
            if token.has_vector:
    # renewable_energy
                for worda in re:
                    doca = nlp(worda)
                    sim = doca.similarity(docb)
                    if sim >= similarity_threshold:
                        simsre[doca[0].text + ' ' + docb[0].text] = sim

    # energy_efficiency
                for wordc in ee:
                    docc = nlp(wordc)
                    sim = docc.similarity(docb)
                    if sim >= similarity_threshold:
                        simsee[docc[0].text + ' ' + docb[0].text] = sim
    
    # pollution_prevention_and_control
                for wordd in ppc:
                    docd = nlp(wordd)
                    sim = docd.similarity(docb)
                    if sim >= similarity_threshold:
                        simsppc[docd[0].text + ' ' + docb[0].text] = sim

    # environmentally_sustainable_management_of_living_natural_resources_and_land_use
                for worde in esml:
                    doce = nlp(worde)
                    sim = doce.similarity(docb)
                    if sim >= similarity_threshold:
                        simsesml[doce[0].text + ' ' + docb[0].text] = sim

    # terrestrial_and_aquatic_biodiversity_conservation
                for wordf in tabc:
                    docf = nlp(wordf)
                    sim = docf.similarity(docb)
                    if sim >= similarity_threshold:
                        simstabc[docf[0].text + ' ' + docb[0].text] = sim

    # clean_transportation
                for wordg in ct:
                    docg = nlp(wordg)
                    sim = docg.similarity(docb)
                    if sim >= similarity_threshold:
                        simsct[docg[0].text + ' ' + docb[0].text] = sim

    # sustainable_water_and_wastewater_management
                for wordh in swwm:
                    doch = nlp(wordh)
                    sim = doch.similarity(docb)
                    if sim >= similarity_threshold:
                        simsswwm[doch[0].text + ' ' + docb[0].text] = sim

    # climate_change_adaptation
                for wordi in cca:
                    doci = nlp(wordi)
                    sim = doci.similarity(docb)
                    if sim >= similarity_threshold:
                        simscca[doci[0].text + ' ' + docb[0].text] = sim
    
    # circular_economy_and_or_ecoefficient_projects
                for wordj in ce:
                    docj = nlp(wordj)
                    sim = docj.similarity(docb)
                    if sim >= similarity_threshold:
                        simsce[docj[0].text + ' ' + docb[0].text] = sim
    
    # green_buildings
                for wordk in gb:
                    dock = nlp(wordk)
                    sim = dock.similarity(docb)
                    if sim >= similarity_threshold:
                        simsgb[dock[0].text + ' ' + docb[0].text] = sim

    if simsre:
        energy_system_uop = True
        cat_count_uop +=1
    else:
        energy_system_uop = False
    if simsee:
        cat_count_uop +=1
    if simsppc:
        cat_count_uop +=1
    if simsesml:
        cat_count_uop +=1
    if simstabc:
        cat_count_uop +=1
    if simsct:
        cat_count_uop +=1
    if simsswwm:
        cat_count_uop +=1
    if simscca:
        cat_count_uop +=1
    if simsce:
        cat_count_uop +=1
    if simsgb:
        cat_count_uop +=1

    return simsre, simsee, simsppc, simsesml, simstabc, simsct, simsswwm, simscca, simsce, simsgb, sim_th_en, sim_th_es, sim_th_pt, energy_system_uop, cat_count_uop

# %%
# list of pdf filenames
pdf_en = ['Green_social_bond_framework_series_ad_ae_2019', 'ISA_CTM_FRAMEWORK', 'SONDA_S_A__GREEN_BOND_FRAMEWORK',
          'CIFI_Green_Bond_Framework', 'BTG_Sustainable_Financing_Framework', 'CABEI_Green_Bond_Framework', 
          'Genneia_Green_Bond_Framework', 'FS_Green_Bond_Framework_-_July_2021', 'CAFs_GREEN_BOND_FRAMEWORK', 
          'BTG_Pactual_Green,_Social_and_Sustainable_Financing_Framework', 'ILAP_Green_Financing_Framework', 
          'EGE_Haina_Green_Securities_Framework', 'CADU_GREEN_BOND_FRAMEWORK', 'Bci_Sustainable_Financing_Framework',
          'FS_Green_Bond_Framework_-_November_2020', 'Sicredi_Green_Bond_Framework', 'Nacional_Financiera_Green_Bond_USD',
          'Green_Bond_Financing_Framework', 'Green_Bond_Framework_of_Banco_Guayaquil', 
          'Marco_de_referencia_de_Bonos_Verdes_Soberanos_de_Colombia', 'Green_Finance_Framework_Interchile']
pdf_en_lines = ['Chile_Sustainable_Bond_Framework', 'Genneia_Green_Financing_Framework']
pdf_es = ['Cartilla_Bonos_Verdes', 'Bono_Azul_-_Framework', 'Marco_de_referencia_de_bono_verde_Coopeguanacaste,_R_L_',  
          'Marco_de_Referencia_del_Bono_Verde_de_la_Ciudad_de_Mexico', 'Nacional_Financiera_Green_Bond_MXN',
          'Marco_de_Gestión_de_Bono_Verde', 'Bono_Verde_de_Bancoldex_Framework']
pdf_es_lines = ['Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos_Verdes,_Sociales_o_Sostenibles_BDP_I']
pdf_pt = ['Green_Bond_Framework', 'Green_Bonds_Framework_Athon_2020']

# %%
# run the pdf through the pipeline - first pdf, initialise the dataframes

# input parameters
document = '/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDF1/Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__in_2021.pdf'
language = 'EN'
tableStrategy = 'lines_strict'

# call the functions in sequence
filename, pdfname, tableCount, tablePages, tableHeaders, tableDFs = catTable(document, tableStrategy)
uniqueCatsNoDupes, table_idx = tableAssess(language, tableCount, tablePages, tableHeaders, tableDFs)
CatwordsFFinal, dfsimScores_cln, simScores_cln, dfresimScores, resimScores, energy_system_tbl, cleanup_TH_en, cleanup_TH_es, cleanup_TH_pt = tableClean(language, uniqueCatsNoDupes)
results_UOP, results_SEEGP = fontInfo(language, document)
max_idx_UOP, max_idx_SEEGP = find_max_font(results_UOP, results_SEEGP)
areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0 = tocCheck(results_UOP, results_SEEGP, max_idx_UOP, max_idx_SEEGP)
keep_areaSEEGP = keepSEEGP(areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0)
UOPwordsNoDupes = wordsUOP(keep_areaSEEGP, document, areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0)

# dataframe output for transparency on how pipeline has processed the pdf
columns = ['pdfname', 'language', 'tableCount', 'areaUOP_page', 'areaUOP_y1', 'areaSEEGP_page', 'areaSEEGP_y0', 'keep_areaSEEGP', 'countUOP_words']
results_df = pd.DataFrame(columns=columns)
results_df.loc[len(results_df)] = [pdfname, language, tableCount, areaUOP_page, areaUOP_y1, areaSEEGP_page,areaSEEGP_y0, keep_areaSEEGP, len(UOPwordsNoDupes)]

# table info
columns = ['pdfname', 'tablePages_list', 'table.Headers_list', 'countCat_words', 'unique compliant Categories_list', 'energy_system_tbl', 'table_idx_list', 'unique Cats all']
table_df = pd.DataFrame(columns=columns)

# UOP start and end info
columns = ['pdfname', 'results_UOP_list (text, fontSize, bbox, page_idx)', 'max_idx_UOP', 'results_SEEGP_list (text, fontSize, bbox, page_idx)', 'max_idx_SEEGP']
UOP_df = pd.DataFrame(columns=columns)
UOP_df.loc[len(UOP_df)] = [pdfname, results_UOP, max_idx_UOP, results_SEEGP, max_idx_SEEGP]

# initialise sim score dicts
ttlsimsre = {}
ttlsimsee = {}
ttlsimsppc = {}
ttlsimsesml = {}
ttlsimstabc = {}
ttlsimsct = {}
ttlsimsswwm = {}
ttlsimscca = {}
ttlsimsce = {}
ttlsimsgb = {}
ttlresimScores = {}
ttlsimScores_cln = {}

# final Cateogory info
if len(uniqueCatsNoDupes) == 0:
    print('')
    print(pdfname)
    print('categories from UOP portion')
    simsre, simsee, simsppc, simsesml, simstabc, simsct, simsswwm, simscca, simsce, simsgb, sim_th_en, sim_th_es, sim_th_pt, energy_system_uop, cat_count_uop = UOPwords_to_Catwords(language, UOPwordsNoDupes)
    columns = ['pdfname', 'energy_system_uop']
    UOP_Words_df = pd.DataFrame(columns=columns)
    UOP_Words_df.loc[len(UOP_Words_df)] = [pdfname, energy_system_uop]
    
    ttlsimsre |= simsre
    ttlsimsee |= simsee
    ttlsimsppc |= simsppc
    ttlsimsesml |= simsesml
    ttlsimstabc |= simstabc
    ttlsimsct |= simsct
    ttlsimsswwm |= simsswwm
    ttlsimscca |= simscca
    ttlsimsce |= simsce
    ttlsimsgb |= simsgb

else:
    print('')
    print(pdfname)
    print('categories from tables')
    table_df.loc[len(table_df)] = [pdfname, tablePages, tableHeaders, len(CatwordsFFinal), CatwordsFFinal, energy_system_tbl, table_idx, uniqueCatsNoDupes]

    ttlresimScores |= resimScores
    ttlsimScores_cln |= simScores_cln

# data table with results, for evaluation to ground truth
# nlp_path 
nlp_path = ""
if len(uniqueCatsNoDupes)>0:
    nlp_path = 'Table'
elif len(uniqueCatsNoDupes)==0 and keep_areaSEEGP == True:
    nlp_path = 'UOP_section_true'
elif len(uniqueCatsNoDupes)==0 and keep_areaSEEGP == False:
    nlp_path = 'UOP_section_false'

# ES percent oucomes
ES_0_percent = False
ES_100_percent = False
ES_partial = False

if energy_system_tbl == False or energy_system_uop == False:
    ES_0_percent = True

elif energy_system_tbl == True:
    if len(CatwordsFFinal) == 1:
        ES_100_percent = True
    elif len(CatwordsFFinal) > 1:
        ES_partial = True

elif energy_system_uop == True:
    if cat_count_uop == 1:
        ES_100_percent = True
    elif cat_count_uop > 1:
        ES_partial = True

# number of cats
number_of_cats = 0
if len(CatwordsFFinal)>0:
    number_of_cats = len(CatwordsFFinal)
else:
    number_of_cats = cat_count_uop

# threshold params
similarity_threshold = 0.0
cleanup_threshold = 0.0
if language == 'EN':
    similarity_threshold = sim_th_en
    cleanup_threshold = cleanup_TH_en
elif language == 'ES':
    similarity_threshold = sim_th_es
    cleanup_threshold = cleanup_TH_es
elif language == 'PT':
    similarity_threshold = sim_th_pt
    cleanup_threshold = cleanup_TH_pt    

columns = ['pdfname', 'nlp_path', 'language', 'similarity_threshold', 'cleanup_threshold', 'ES_0_percent', 'ES_100_percent', 'ES_partial', 'number_of_cats']
pred_train_rpts = pd.DataFrame(columns=columns)
pred_train_rpts.loc[len(pred_train_rpts)] = [pdfname, nlp_path, language, similarity_threshold, cleanup_threshold, ES_0_percent, ES_100_percent, ES_partial, number_of_cats]
# Out:
# Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__in_2021
# categories from UOP portion

# %%
# run the pdf through the pipeline - subsequent pdfs, populate the dataframes


# input parameters
filepath = '/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/PDFs/'
extention = '.pdf'
language = 'ES'
tableStrategy = 'lines'

for pdf in pdf_es_lines:
    document = filepath + pdf + extention

    # call the functions in sequence
    filename, pdfname, tableCount, tablePages, tableHeaders, tableDFs = catTable(document, tableStrategy)
    uniqueCatsNoDupes, table_idx = tableAssess(language, tableCount, tablePages, tableHeaders, tableDFs)
    CatwordsFFinal, dfsimScores_cln, simScores_cln, dfresimScores, resimScores, energy_system_tbl, cleanup_TH_en, cleanup_TH_es, cleanup_TH_pt = tableClean(language, uniqueCatsNoDupes) 
    results_UOP, results_SEEGP = fontInfo(language, document)
    max_idx_UOP, max_idx_SEEGP = find_max_font(results_UOP, results_SEEGP)
    areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0 = tocCheck(results_UOP, results_SEEGP, max_idx_UOP, max_idx_SEEGP)
    keep_areaSEEGP = keepSEEGP(areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0)
    UOPwordsNoDupes = wordsUOP(keep_areaSEEGP, document, areaUOP_page, areaUOP_y1, areaSEEGP_page, areaSEEGP_y0)

    # dataframe outputs for transparency on how pipeline has processed the pdf
    results_df.loc[len(results_df)] = [pdfname, language, tableCount, areaUOP_page, areaUOP_y1, areaSEEGP_page,areaSEEGP_y0, keep_areaSEEGP, len(UOPwordsNoDupes)]
    UOP_df.loc[len(UOP_df)] = [pdfname, results_UOP, max_idx_UOP, results_SEEGP, max_idx_SEEGP]

    # final Cateogory info
    if len(uniqueCatsNoDupes) == 0:
        print('')
        print(pdfname)
        print('categories from UOP portion')
        simsre, simsee, simsppc, simsesml, simstabc, simsct, simsswwm, simscca, simsce, simsgb, sim_th_en, sim_th_es, sim_th_pt, energy_system_uop, cat_count_uop = UOPwords_to_Catwords(language, UOPwordsNoDupes)
        UOP_Words_df.loc[len(UOP_Words_df)] = [pdfname, energy_system_uop]

        ttlsimsre |= simsre
        ttlsimsee |= simsee
        ttlsimsppc |= simsppc
        ttlsimsesml |= simsesml
        ttlsimstabc |= simstabc
        ttlsimsct |= simsct
        ttlsimsswwm |= simsswwm
        ttlsimscca |= simscca
        ttlsimsce |= simsce
        ttlsimsgb |= simsgb

    else:
        print('')
        print(pdfname)
        print('categories from tables')
        table_df.loc[len(table_df)] = [pdfname, tablePages, tableHeaders, len(CatwordsFFinal), CatwordsFFinal, energy_system_tbl, table_idx, uniqueCatsNoDupes]

        ttlresimScores |= resimScores
        ttlsimScores_cln |= simScores_cln


    # data table with results for evaluation to ground truth
    # nlp_path 
    nlp_path = ""
    if len(uniqueCatsNoDupes)>0:
        nlp_path = 'Table'
    elif len(uniqueCatsNoDupes)==0 and keep_areaSEEGP == True:
        nlp_path = 'UOP_section_true'
    elif len(uniqueCatsNoDupes)==0 and keep_areaSEEGP == False:
        nlp_path = 'UOP_section_false'

    # ES percent oucomes
    ES_0_percent = False
    ES_100_percent = False
    ES_partial = False

    if energy_system_tbl == False or energy_system_uop == False:
        ES_0_percent = True

    elif energy_system_tbl == True:
        if len(CatwordsFFinal) == 1:
            ES_100_percent = True
        elif len(CatwordsFFinal) > 1:
            ES_partial = True

    elif energy_system_uop == True:
        if cat_count_uop == 1:
            ES_100_percent = True
        elif cat_count_uop > 1:
            ES_partial = True

    # number of cats
    number_of_cats = 0
    if len(CatwordsFFinal)>0:
        number_of_cats = len(CatwordsFFinal)
    else:
        number_of_cats = cat_count_uop

    # threshold params
    similarity_threshold = 0.0
    cleanup_threshold = 0.0
    if language == 'EN':
        similarity_threshold = sim_th_en
        cleanup_threshold = cleanup_TH_en
    elif language == 'ES':
        similarity_threshold = sim_th_es
        cleanup_threshold = cleanup_TH_es
    elif language == 'PT':
        similarity_threshold = sim_th_pt
        cleanup_threshold = cleanup_TH_pt

    
    pred_train_rpts.loc[len(pred_train_rpts)] = [pdfname, nlp_path, language, similarity_threshold, cleanup_threshold, ES_0_percent, ES_100_percent, ES_partial, number_of_cats]
# Out:
# /var/folders/pf/t466z2553r9f82s2v7n0pgfr0000gn/T/ipykernel_6510/2055448953.py:45: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   simScore_cln = docCat.similarity(docx) # compare each cat phrase to all ref words
# /var/folders/pf/t466z2553r9f82s2v7n0pgfr0000gn/T/ipykernel_6510/2055448953.py:57: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   resimScore = wordy.similarity(doca) # compare each word (token) in each cat phrase to renewable energy ref words
# Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos_Verdes,_Sociales_o_Sostenibles_BDP_I
# categories from tables

# %%
results_df
# Out:
#                                               pdfname language  tableCount  \
# 0   Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...       EN           1
# 1                               Cartilla_Bonos_Verdes       ES           0
# 2                               Bono_Azul_-_Framework       ES           5
# 3   Marco_de_referencia_de_bono_verde_Coopeguanaca...       ES          18
# 4   Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...       ES           0
# 5                  Nacional_Financiera_Green_Bond_MXN       ES           6
# 6                     Marco_de_Gestión_de_Bono_Verde       ES           3
# 7                   Bono_Verde_de_Bancoldex_Framework       ES           1
# 8                    Chile_Sustainable_Bond_Framework       EN          13
# 9                   Genneia_Green_Financing_Framework       EN           2
# 10      Green_social_bond_framework_series_ad_ae_2019       EN           3
# 11                                  ISA_CTM_FRAMEWORK       EN          11
# 12                    SONDA_S_A__GREEN_BOND_FRAMEWORK       EN           0
# 13                          CIFI_Green_Bond_Framework       EN           0
# 14                BTG_Sustainable_Financing_Framework       EN           1
# 15                         CABEI_Green_Bond_Framework       EN           5
# 16                       Genneia_Green_Bond_Framework       EN           0
# 17                FS_Green_Bond_Framework_-_July_2021       EN           0
# 18                          CAFs_GREEN_BOND_FRAMEWORK       EN           6
# 19  BTG_Pactual_Green,_Social_and_Sustainable_Fina...       EN           4
# 20                     ILAP_Green_Financing_Framework       EN           0
# 21               EGE_Haina_Green_Securities_Framework       EN           1
# 22                          CADU_GREEN_BOND_FRAMEWORK       EN           0
# 23                Bci_Sustainable_Financing_Framework       EN           0
# 24            FS_Green_Bond_Framework_-_November_2020       EN           0
# 25                       Sicredi_Green_Bond_Framework       EN           2
# 26                 Nacional_Financiera_Green_Bond_USD       EN           1
# 27                     Green_Bond_Financing_Framework       EN           3
# 28            Green_Bond_Framework_of_Banco_Guayaquil       EN          16
# 29  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...       EN           1
# 30                 Green_Finance_Framework_Interchile       EN           1
# 31                               Green_Bond_Framework       PT           5
# 32                   Green_Bonds_Framework_Athon_2020       PT           2
# 33  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...       ES          43
#
#     areaUOP_page  areaUOP_y1  areaSEEGP_page  areaSEEGP_y0  keep_areaSEEGP  \
# 0              1  420.328369               2    354.484863            True
# 1             10  433.616699              16    464.230499            True
# 2              1  336.792603               1    390.216888            True
# 3             15   89.151588              16    541.706238            True
# 4              0  490.869995               0    395.050018           False
# 5              3  188.569992               3    534.459961            True
# 6              7  411.209991               2    210.830017           False
# 7              1  492.789978               3    365.630005            True
# 8             18  217.077713               3    216.104080           False
# 9              1  600.482239               0      0.000000           False
# 10             1   98.540031               1     87.500031           False
# 11             8  271.757019               3    201.050018           False
# 12             4  124.099983               4    435.190002            True
# 13             7  569.777405               8    169.974762            True
# 14            20   80.458229              31     60.549740            True
# 15             7  441.189972              11     81.259979            True
# 16             8  110.361000               9    104.296997            True
# 17            11  455.748077               5    223.619537           False
# 18             7  262.438385               9    336.903778            True
# 19            14  406.338043              18    499.063019            True
# 20             0  481.347198               0    470.681610           False
# 21            10  492.464996              12    428.401001            True
# 22             6  140.128403               0    758.464783           False
# 23             7  110.545990               1     28.432018           False
# 24             7  546.994019               7    403.429993           False
# 25             3  402.529999               4    579.070007            True
# 26             3  123.770012               3    356.360016            True
# 27             7  179.089981               8    559.180054            True
# 28             6  109.511734              11     71.712212            True
# 29            14  479.131409              19    351.234100            True
# 30             7  321.529999               9    111.740021            True
# 31             1  304.611969              15    133.837967            True
# 32             4  428.291565               6    551.981140            True
# 33             5  102.917595              32    535.163818            True
#
#     countUOP_words
# 0              188
# 1              497
# 2               15
# 3              271
# 4              818
# 5               99
# 6              400
# 7              325
# 8             1443
# 9             1267
# 10             927
# 11             503
# 12             124
# 13              66
# 14            1311
# 15             387
# 16             169
# 17             679
# 18             271
# 19             327
# 20             910
# 21             275
# 22             578
# 23             909
# 24             653
# 25             236
# 26              84
# 27             186
# 28             622
# 29             731
# 30             210
# 31            1602
# 32             379
# 33            2949

# %%
table_df
# Out:
#                                               pdfname  \
# 0                  Nacional_Financiera_Green_Bond_MXN
# 1                     Marco_de_Gestión_de_Bono_Verde
# 2                    Chile_Sustainable_Bond_Framework
# 3                   Genneia_Green_Financing_Framework
# 4       Green_social_bond_framework_series_ad_ae_2019
# 5                                   ISA_CTM_FRAMEWORK
# 6                          CABEI_Green_Bond_Framework
# 7                           CAFs_GREEN_BOND_FRAMEWORK
# 8   BTG_Pactual_Green,_Social_and_Sustainable_Fina...
# 9                        Sicredi_Green_Bond_Framework
# 10                     Green_Bond_Financing_Framework
# 11            Green_Bond_Framework_of_Banco_Guayaquil
# 12                 Green_Finance_Framework_Interchile
# 13                               Green_Bond_Framework
# 14  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...
#
#                                       tablePages_list  \
# 0                                  [3, 9, 10, 11, 17]
# 1                                           [5, 8, 9]
# 2   [0, 19, 20, 21, 22, 23, 24, 25, 26, 30, 37, 38...
# 3                                              [5, 7]
# 4                                           [3, 6, 7]
# 5                     [4, 5, 7, 8, 9, 15, 16, 17, 18]
# 6                                   [7, 8, 9, 10, 12]
# 7                                        [1, 2, 8, 9]
# 8                                    [15, 16, 17, 19]
# 9                                              [4, 6]
# 10                                         [7, 8, 10]
# 11       [6, 7, 8, 9, 10, 18, 19, 29, 30, 31, 38, 39]
# 12                                                [8]
# 13                               [10, 14, 19, 21, 22]
# 14  [3, 4, 8, 16, 18, 19, 20, 21, 22, 23, 24, 25, ...
#
#                                    table.Headers_list  countCat_words  \
# 0   [[Categoría, Actividades elegibles], [Col0, Pr...               2
# 1   [[Norma de\nDesempeño, Estatus1, Descripción],...               1
# 2   [[Col0, Ministry of\nFinance\nGovernment of Ch...               8
# 3   [[Col0, 20161, 20202, 20251, 20301], [Eligible...               1
# 4   [[Category, Project name, Goal], [Categories o...               2
# 5   [[Eligible Project Category, Questions, Alignm...               2
# 6   [[Eligible\nGreen\nProjects\nCategories, Sub-c...               3
# 7   [[Measure of Units, Col1], [Graphics, Content]...               4
# 8   [[Green\nProject\nCategory, Use of\nProceeds, ...               6
# 9   [[Eligible\nCategories, Description, Objective...               2
# 10  [[Eligible Category aligned\nwith ICMA Green B...               2
# 11  [[GBP Eligible\nGreen Assets\nCategory, Banco ...               2
# 12  [[Eligible Project Category, Questions, Alignm...               3
# 13  [[Categoria, Descrição], [Projeto, Capaci\nda ...               2
# 14  [[Contribuciones Nacionales Determinadas (NDCs...               1
#
#                      unique compliant Categories_list  energy_system_tbl  \
# 0   [pequeñas centrales hidroeléctricas, centrales...               True
# 1   [proyecto de energías renovables (energía hidr...               True
# 2   [energy efficiency, access to basic housing, r...               True
# 3                                  [renewable energy]               True
# 4                  [potable water supply, sanitation]              False
# 5               [energy efficiency, renewable energy]               True
# 6   [renewable energy, sustainable land use, water...               True
# 7   [clean transportation, renewable energy, waste...               True
# 8   [clean transportation, sustainable water and w...               True
# 9               [energy efficiency, renewable energy]               True
# 10          [clean transportation, energy efficiency]              False
# 11              [energy efficiency, renewable energy]               True
# 12  [energy efficiency, renewable energy, climate ...               True
# 13        [transmissão de energia, energia renovável]               True
# 14                              [energías renovables]              False
#
#                                        table_idx_list  \
# 0                                              [0, 0]
# 1                                                 [1]
# 2   [5, 5, 5, 5, 6, 6, 7, 7, 7, 8, 8, 10, 10, 10, ...
# 3                                                 [1]
# 4                                  [0, 0, 0, 1, 1, 1]
# 5                                              [0, 0]
# 6                                     [0, 4, 4, 4, 4]
# 7                                        [2, 2, 2, 2]
# 8          [0, 1, 1, 1, 1, 2, 2, 3, 3, 3, 3, 3, 3, 3]
# 9                                              [0, 0]
# 10                                          [0, 2, 2]
# 11                                    [0, 1, 1, 1, 1]
# 12                                          [0, 0, 0]
# 13                                             [0, 0]
# 14                           [34, 34, 34, 34, 35, 35]
#
#                                       unique Cats all
# 0   [pequeñas centrales hidroeléctricas, centrales...
# 1   [proyecto de energías renovables (energía hidr...
# 2   [support for the community through job creatio...
# 3                                  [renewable energy]
# 4   [potable water supply, sanitation, resilient i...
# 5               [energy efficiency, renewable energy]
# 6   [clean transport, renewable energy, sustainabl...
# 7   [clean transportation, renewable energy, waste...
# 8   [clean transportation, sustainable water and w...
# 9               [energy efficiency, renewable energy]
# 10          [clean transportation, energy efficiency]
# 11              [energy efficiency, renewable energy]
# 12  [renewable energy, energy efficiency, climate ...
# 13        [transmissão de energia, energia renovável]
# 14  [verdes, energías renovables, eficiencia energ...

# %%
check11 = table_df.iloc[11].loc['simScores for ES']
check11
# Out:
#                   0
# renewable  0.682400
# power      0.657853
# bioenergy  0.651106
# biofuel    0.690298
# biomass    0.675836

# %%
UOP_df
# Out:
#                                               pdfname  \
# 0   Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...
# 1                               Cartilla_Bonos_Verdes
# 2                               Bono_Azul_-_Framework
# 3   Marco_de_referencia_de_bono_verde_Coopeguanaca...
# 4   Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...
# 5                  Nacional_Financiera_Green_Bond_MXN
# 6                     Marco_de_Gestión_de_Bono_Verde
# 7                   Bono_Verde_de_Bancoldex_Framework
# 8                    Chile_Sustainable_Bond_Framework
# 9                   Genneia_Green_Financing_Framework
# 10      Green_social_bond_framework_series_ad_ae_2019
# 11                                  ISA_CTM_FRAMEWORK
# 12                    SONDA_S_A__GREEN_BOND_FRAMEWORK
# 13                          CIFI_Green_Bond_Framework
# 14                BTG_Sustainable_Financing_Framework
# 15                         CABEI_Green_Bond_Framework
# 16                       Genneia_Green_Bond_Framework
# 17                FS_Green_Bond_Framework_-_July_2021
# 18                          CAFs_GREEN_BOND_FRAMEWORK
# 19  BTG_Pactual_Green,_Social_and_Sustainable_Fina...
# 20                     ILAP_Green_Financing_Framework
# 21               EGE_Haina_Green_Securities_Framework
# 22                          CADU_GREEN_BOND_FRAMEWORK
# 23                Bci_Sustainable_Financing_Framework
# 24            FS_Green_Bond_Framework_-_November_2020
# 25                       Sicredi_Green_Bond_Framework
# 26                 Nacional_Financiera_Green_Bond_USD
# 27                     Green_Bond_Financing_Framework
# 28            Green_Bond_Framework_of_Banco_Guayaquil
# 29  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...
# 30                 Green_Finance_Framework_Interchile
# 31                               Green_Bond_Framework
# 32                   Green_Bonds_Framework_Athon_2020
# 33  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...
#
#     results_UOP_list (text, fontSize, bbox, page_idx)  max_idx_UOP  \
# 0   [(Use of Proceeds  , 11.039999961853027, (85.1...            0
# 1   [(Uso de Fondos Proyectos Verdes Elegibles , 1...            3
# 2   [(2.1 Uso de los recursos , 12.0, (41.13280105...            0
# 3   [(Destinos de Fondos. ...........................            1
# 4   [(1. Uso de los Recursos , 12.0, (49.680000305...            0
# 5   [(3.1. Uso de los Fondos , 11.039999961853027,...            1
# 6   [(Uso de los Fondos .............................            2
# 7   [(Uso de los recursos , 12.0, (113.41999816894...            0
# 8   [(Use of Proceeds, 8.0, (311.42449951171875, 5...            2
# 9   [(Use of proceeds, 9.0, (73.48359680175781, 58...            0
# 10  [(SBPs: Use of Funds, Evaluation and Selection...            0
# 11  [(Use of the proceeds , 11.039999961853027, (1...            4
# 12  [(3.1 Use of Proceeds ...........................            1
# 13  [(a. Use of Proceeds, 12.531599998474121, (69....            0
# 14  [(Use of Proceeds, 13.0, (241.72439575195312, ...            2
# 15  [(Use of Proceeds ...............................            1
# 16  [(  Use of Proceeds, 13.0, (253.3719940185547,...            1
# 17  [(Use of Proceeds , 12.000450134277344, (110.6...            0
# 18  [(1. Use of Proceeds ............................            2
# 19  [(Use of Proceeds , 12.0, (184.590087890625, 6...            3
# 20  [(1. Use of proceeds , 8.800000190734863, (77....            0
# 21  [(• Use of Proceeds\t, 10.0, (259.912902832031...            5
# 22  [(Use of Proceeds , 11.039999961853027, (84.98...            0
# 23  [(Green Use of Proceeds instruments: , 9.0, (6...           10
# 24  [(Use of Proceeds , 12.0, (110.66000366210938,...            0
# 25  [(2.1 Use of Proceeds ...........................            2
# 26  [(3.1 Use of Proceeds , 11.039999961853027, (9...            2
# 27  [(Use of Proceeds , 11.039999961853027, (108.0...            1
# 28  [(First Principle – Use of Proceeds .............            3
# 29  [(Use of proceeds , 11.0, (360.3396911621094, ...            3
# 30  [(4.1 Use of Proceeds ...........................            2
# 31  [(Usos dos Recursos , 12.0, (115.25, 291.32797...            0
# 32  [(Uso de Recursos ...............................            2
# 33  [(Marco de uso de fondos para las emisiones de...            7
#
#    results_SEEGP_list (text, fontSize, bbox, page_idx)  max_idx_SEEGP
# 0   [(Selection and Evaluation of Eligible Green P...               0
# 1   [(Procedimiento Selección y Evaluación , 12.0,...               2
# 2   [(2.2  Proceso de evaluación y selección de pr...               0
# 3   [(Proceso de evaluación y selección de proyect...               2
# 4   [(2. Proceso de Evaluación y Selección de proy...               0
# 5   [(3.2. Proceso de Evaluación y Selección de Pr...               2
# 6   [(Proceso de Selección y Evaluación de Proyect...               1
# 7   [(ingresos o recursos; (ii) proceso de evaluac...               2
# 8   [(Project Evaluation , 11.0, (123.502014160156...               0
# 9                                                  []               0
# 10  [(SBPs: Use of Funds, Evaluation and Selection...               0
# 11  [(Process for Evaluation and Selection , 11.03...               0
# 12  [(3.2 Project Selection and Assessment Process...               1
# 13  [(b. Project Selection Criteria , 12.531599998...               0
# 14  [(Process for Project Selection and Evaluation...               4
# 15  [(Process for Project Evaluation and Selection...               3
# 16  [(Process for Project Evaluation  , 13.0, (269...               2
# 17  [(theme within the company. Furthermore, in th...               0
# 18  [(2. Process for Project Evaluation and Select...               6
# 19  [(Process for Project , 12.0, (184.59008789062...               5
# 20  [( 2. Process for project evaluation and selec...               0
# 21  [(• Project Selection and Evaluation Process\t...               1
# 22  [(selection processes; and, the reporting meth...               0
# 23  [(Process for , 9.0, (277.7300109863281, 28.43...               0
# 24  [(Capital Markets Association are voluntary pr...               0
# 25  [(2.2 Project evaluation & selection ............               3
# 26  [(3.2 Project Selection Process , 11.039999961...               1
# 27  [(5.2      Process of Project Evaluation and S...               5
# 28  [(Second Principle – Process for Project Evalu...               6
# 29  [(Process for Project Evaluation and , 11.0, (...               5
# 30  [(4.2 Process for Project Evaluation and Selec...               5
# 31  [(Avaliação e Seleção de Ativos , 12.0, (103.2...               0
# 32  [(Processo de Avaliação e Seleção de Projetos ...               1
# 33  [(3.2. Selección y Evaluación de Proyectos ......               2

# %%
UOP_Words_df
# Out:
#                                               pdfname  energy_system_uop
# 0   Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...               True
# 1                               Cartilla_Bonos_Verdes               True
# 2                               Bono_Azul_-_Framework              False
# 3   Marco_de_referencia_de_bono_verde_Coopeguanaca...               True
# 4   Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...               True
# 5                   Bono_Verde_de_Bancoldex_Framework               True
# 6                     SONDA_S_A__GREEN_BOND_FRAMEWORK               True
# 7                           CIFI_Green_Bond_Framework               True
# 8                 BTG_Sustainable_Financing_Framework               True
# 9                        Genneia_Green_Bond_Framework               True
# 10                FS_Green_Bond_Framework_-_July_2021               True
# 11                     ILAP_Green_Financing_Framework               True
# 12               EGE_Haina_Green_Securities_Framework               True
# 13                          CADU_GREEN_BOND_FRAMEWORK              False
# 14                Bci_Sustainable_Financing_Framework               True
# 15            FS_Green_Bond_Framework_-_November_2020               True
# 16                 Nacional_Financiera_Green_Bond_USD               True
# 17  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...               True
# 18                   Green_Bonds_Framework_Athon_2020               True

# %%
pred_train_rpts
# Out:
#                                               pdfname           nlp_path  \
# 0   Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...   UOP_section_true
# 1                               Cartilla_Bonos_Verdes   UOP_section_true
# 2                               Bono_Azul_-_Framework   UOP_section_true
# 3   Marco_de_referencia_de_bono_verde_Coopeguanaca...   UOP_section_true
# 4   Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...  UOP_section_false
# 5                  Nacional_Financiera_Green_Bond_MXN              Table
# 6                     Marco_de_Gestión_de_Bono_Verde              Table
# 7                   Bono_Verde_de_Bancoldex_Framework   UOP_section_true
# 8                    Chile_Sustainable_Bond_Framework              Table
# 9                   Genneia_Green_Financing_Framework              Table
# 10      Green_social_bond_framework_series_ad_ae_2019              Table
# 11                                  ISA_CTM_FRAMEWORK              Table
# 12                    SONDA_S_A__GREEN_BOND_FRAMEWORK   UOP_section_true
# 13                          CIFI_Green_Bond_Framework   UOP_section_true
# 14                BTG_Sustainable_Financing_Framework   UOP_section_true
# 15                         CABEI_Green_Bond_Framework              Table
# 16                       Genneia_Green_Bond_Framework   UOP_section_true
# 17                FS_Green_Bond_Framework_-_July_2021  UOP_section_false
# 18                          CAFs_GREEN_BOND_FRAMEWORK              Table
# 19  BTG_Pactual_Green,_Social_and_Sustainable_Fina...              Table
# 20                     ILAP_Green_Financing_Framework  UOP_section_false
# 21               EGE_Haina_Green_Securities_Framework   UOP_section_true
# 22                          CADU_GREEN_BOND_FRAMEWORK  UOP_section_false
# 23                Bci_Sustainable_Financing_Framework  UOP_section_false
# 24            FS_Green_Bond_Framework_-_November_2020  UOP_section_false
# 25                       Sicredi_Green_Bond_Framework              Table
# 26                 Nacional_Financiera_Green_Bond_USD   UOP_section_true
# 27                     Green_Bond_Financing_Framework              Table
# 28            Green_Bond_Framework_of_Banco_Guayaquil              Table
# 29  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...   UOP_section_true
# 30                 Green_Finance_Framework_Interchile              Table
# 31                               Green_Bond_Framework              Table
# 32                   Green_Bonds_Framework_Athon_2020   UOP_section_true
# 33  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...              Table
#
#    language  similarity_threshold  cleanup_threshold  ES_0_percent  \
# 0        EN                   0.8               0.65         False
# 1        ES                   0.8               0.65         False
# 2        ES                   0.8               0.65          True
# 3        ES                   0.8               0.65         False
# 4        ES                   0.8               0.65         False
# 5        ES                   0.8               0.65         False
# 6        ES                   0.8               0.65         False
# 7        ES                   0.8               0.65         False
# 8        EN                   0.8               0.65         False
# 9        EN                   0.8               0.65         False
# 10       EN                   0.8               0.65          True
# 11       EN                   0.8               0.65         False
# 12       EN                   0.8               0.65         False
# 13       EN                   0.8               0.65         False
# 14       EN                   0.8               0.65         False
# 15       EN                   0.8               0.65         False
# 16       EN                   0.8               0.65         False
# 17       EN                   0.8               0.65         False
# 18       EN                   0.8               0.65         False
# 19       EN                   0.8               0.65         False
# 20       EN                   0.8               0.65         False
# 21       EN                   0.8               0.65         False
# 22       EN                   0.8               0.65          True
# 23       EN                   0.8               0.65         False
# 24       EN                   0.8               0.65         False
# 25       EN                   0.8               0.65         False
# 26       EN                   0.8               0.65         False
# 27       EN                   0.8               0.65          True
# 28       EN                   0.8               0.65         False
# 29       EN                   0.8               0.65         False
# 30       EN                   0.8               0.65         False
# 31       PT                   0.8               0.65         False
# 32       PT                   0.8               0.65         False
# 33       ES                   0.8               0.65          True
#
#     ES_100_percent  ES_partial  number_of_cats
# 0             True       False               1
# 1            False        True               8
# 2            False       False               2
# 3            False        True               7
# 4            False        True               8
# 5            False        True               2
# 6             True       False               1
# 7            False        True               7
# 8            False        True               8
# 9             True       False               1
# 10           False       False               2
# 11           False        True               2
# 12           False        True               4
# 13           False        True               4
# 14           False        True              10
# 15           False        True               3
# 16           False        True               2
# 17           False        True               4
# 18           False        True               4
# 19           False        True               6
# 20           False        True               4
# 21           False        True               4
# 22           False       False               4
# 23           False        True               6
# 24           False        True               4
# 25           False        True               2
# 26            True       False               1
# 27           False       False               2
# 28           False        True               2
# 29           False        True              10
# 30           False        True               3
# 31           False        True               2
# 32           False        True               4
# 33           False       False               1

# %%
import statistics
import numpy as np

# %%
cleanup_th_med = statistics.median(ttlsimScores_cln.values())
cleanup_th_25 = np.percentile(list(ttlsimScores_cln.values()), 25)
re_tbl_th_med = statistics.median(ttlresimScores.values())
re_tbl_th_25 = np.percentile(list(ttlresimScores.values()),25)
re_uop_th_med = statistics.median(ttlsimsre.values())
re_uop_th_25 = np.percentile(list(ttlsimsre.values()),25)
ee_uop_th_med = statistics.median(ttlsimsee.values())
ee_uop_th_25 = np.percentile(list(ttlsimsee.values()), 25)
cca_uop_th_med = statistics.median(ttlsimscca.values())
cca_uop_th_25 = np.percentile(list(ttlsimscca.values()), 25)
ppc_uop_th_med = statistics.median(ttlsimsppc.values())
ppc_uop_th_25 = np.percentile(list(ttlsimsppc.values()), 25)
tabc_uop_th_med = statistics.median(ttlsimstabc.values())
tabc_uop_th_25 = np.percentile(list(ttlsimstabc.values()), 25)
esml_uop_th_med = statistics.median(ttlsimsesml.values())
esml_uop_th_25 = np.percentile(list(ttlsimsesml.values()), 25)
ct_uop_th_med = statistics.median(ttlsimsct.values())
ct_uop_th_25 = np.percentile(list(ttlsimsct.values()), 25)
ce_uop_th_med = statistics.median(ttlsimsce. values())
ce_uop_th_25 = np.percentile(list(ttlsimsce. values()), 25)
swwm_uop_th_med = statistics.median(ttlsimsswwm.values())
swwm_uop_th_25 = np.percentile(list(ttlsimsswwm.values()), 25)
gb_uop_th_med = statistics.median(ttlsimsgb.values())
gb_uop_th_25 = np.percentile(list(ttlsimsgb.values()), 25)

# %%
V5_th_list = [cleanup_th_med, cleanup_th_25, re_tbl_th_med, re_tbl_th_25, re_uop_th_med, re_uop_th_25, ee_uop_th_med,
              ee_uop_th_25, cca_uop_th_med, cca_uop_th_25, ppc_uop_th_med, ppc_uop_th_25, tabc_uop_th_med, tabc_uop_th_25,
              esml_uop_th_med, esml_uop_th_25, ct_uop_th_med, ct_uop_th_25, ce_uop_th_med, ce_uop_th_25, swwm_uop_th_med,
              swwm_uop_th_25, gb_uop_th_med, gb_uop_th_25]

# %%
columns = ['ttlsimScores_cln', 'ttlresimScores', 'ttlsimsre', 'ttlsimsee', 'ttlsimsppc', 'ttlsimsesml', 'ttlsimstabc', 'ttlsimsct', 'ttlsimscca', 'ttlsimsce', 'ttlsimsswwm', 'ttlsimsgb', 'V5_th_list']
sims_dicts_V5 = pd.DataFrame(columns=columns)
sims_dicts_V5.loc[len(sims_dicts_V5)] = [ttlsimScores_cln, ttlresimScores, ttlsimsre, ttlsimsee, ttlsimsppc, ttlsimsesml, ttlsimstabc, ttlsimsct, ttlsimscca, ttlsimsce, ttlsimsswwm, ttlsimsgb, V5_th_list]
sims_dicts_V5.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/sims_dicts_V5.csv')

# %%
ttlsimScores_cln
# Out:
# {'pequeñas centrales hidroeléctricas hidroelectricidad': 0.7128672003746033,
#  'pequeñas centrales hidroeléctricas construcciones': 0.7090030908584595,
#  'centrales eólicas (solo terrestres) cuadrícula (sólo)': 0.8724079728126526,
#  'proyecto de energías renovables (energía hidroeléctrica – contribución a mitigación del cambio climático) de alimentos': 0.6540133953094482,
#  'energy efficiency renewable': 0.665412187576294,
#  'energy efficiency efficiency': 0.9004887938499451,
#  'access to basic housing housing': 0.6902390718460083,
#  'renewable energy renewable': 0.9201155304908752,
#  'renewable energy solar': 0.7037988305091858,
#  'access to affordable housing housing': 0.7369170188903809,
#  'green buildings (ecological buildings) buildings': 0.8016582131385803,
#  'natural resources, use of land and protected marine areas land': 0.6691650152206421,
#  'food security food': 0.7798810005187988,
#  'water management water': 0.8119471073150635,
#  'potable water supply water': 0.8469440937042236,
#  'potable water supply potable': 0.8287600874900818,
#  'sanitation sanitation': 1.0,
#  'sustainable land use land': 0.7586947083473206,
#  'clean transportation transportation': 0.8166900873184204,
#  'waste management waste': 0.8286465406417847,
#  'sustainable management of living natural resources and land use land': 0.6743867993354797,
#  'sustainable water and wastewater management waste': 0.6586280465126038,
#  'sustainable water and wastewater management water': 0.7551437616348267,
#  'sustainable water and wastewater management wastewater': 0.7414587140083313,
#  'green buildings buildings': 0.839942991733551,
#  'energy efcfi iency renewable': 0.6823998093605042,
#  'energy efcfi iency power': 0.6578531861305237,
#  'afof rdable housing housing': 1.0,
#  'climate change adaptation adaptation': 0.7083937525749207,
#  'transmissão de energia energia hidráulica': 0.6504395604133606,
#  'energia renovável energia': 0.9140269160270691,
#  'energia renovável bioenergia': 0.72825026512146,
#  'energia renovável biocombustível': 0.7220384478569031,
#  'energia renovável biomassa': 0.716290295124054,
#  'energia renovável energia hidráulica': 0.8522579669952393,
#  'energías renovables renovable': 0.7062243223190308,
#  'energías renovables bioenergía': 0.7306941151618958,
#  'energías renovables hidroelectricidad': 0.6826406717300415}

# %%
ttlresimScores
# Out:
# {'hidroelectricidad': 0.8112889528274536,
#  'cuadrícula (sólo)': 0.9524129033088684,
#  'bioenergía': 0.8198481798171997,
#  'Hidroeléctrico': 0.8471897840499878,
#  'renewable': 1.0,
#  'transmissão': 1.0,
#  'energia': 1.0,
#  'energia hidráulica': 0.9084943532943726}

# %%
ttlsimsre
# Out:
# {'generation generation': 1.0,
#  'power power': 1.0,
#  'renewable renewable': 1.0,
#  'solar solar': 1.0,
#  'transmission transmission': 1.0,
#  'biocombustible combustible': 0.8335129022598267,
#  'generación generación': 1.0,
#  'bioenergía energía': 0.8198480606079102,
#  'cuadrícula (': 0.9473557472229004,
#  'cuadrícula iii': 0.8252873420715332,
#  'cuadrícula plasma': 0.8057650327682495,
#  'cuadrícula futuros': 0.8777064085006714,
#  'generación transformación': 0.8076272010803223,
#  'cuadrícula totales': 0.892815351486206,
#  'cuadrícula vehículos': 0.8071877360343933,
#  'biomasa biomasa': 1.0,
#  'cuadrícula tecnología': 0.8814537525177002,
#  'cuadrícula financiamiento': 0.8732093572616577,
#  'potencia capacidad': 0.8051767349243164,
#  'cuadrícula )': 0.8254541158676147,
#  'hidroelectricidad hidroeléctricos': 0.8131045699119568,
#  'renovable renovable': 1.0,
#  'hidroelectricidad hidroeléctricas': 0.8153160214424133,
#  'generación cogeneración': 0.8619147539138794,
#  'cuadrícula atmosféricas': 0.807408332824707,
#  'wind wind': 1.0,
#  'biomass biomass': 1.0,
#  'hydropower hydropower': 1.0,
#  'hydroelectric hydropower': 0.885119616985321,
#  'grid grid': 0.8339791297912598,
#  'biofuel biofuel': 1.0,
#  'hydrogen hydrogen': 1.0,
#  'grid grids': 0.8352745771408081,
#  'energia energia': 0.9084944128990173,
#  'geração geração': 1.0}

# %%
ttlsimscca
# Out:
# {'adecuación evaluación': 0.8495463132858276,
#  'adecuación implementación': 0.8621118664741516,
#  'adecuación integración': 0.8163694739341736,
#  'adecuación planeación': 0.808627724647522,
#  'adecuación renovación': 0.8079515099525452,
#  'adecuación utilización': 0.8224044442176819,
#  'adecuación habilitación': 0.8525652289390564,
#  'adecuación fiscalización': 0.8114882707595825,
#  'adecuación realización': 0.8257564902305603,
#  'adecuación gasificación': 0.8322635889053345,
#  'adecuación reutilización': 0.829303503036499,
#  'adecuación transformación': 0.8015757203102112,
#  'adecuación asignación': 0.8254500031471252,
#  'adecuación adaptación': 0.816444456577301,
#  'adecuación validación': 0.8463414311408997,
#  'adecuación regulación': 0.8415524363517761,
#  'adecuación adecuaciones': 0.806394100189209,
#  'adecuación optimización': 0.8359052538871765,
#  'adecuación modernización': 0.8007344603538513,
#  'adecuación incorporación': 0.8026008009910583,
#  'adaptation adaptation': 1.0,
#  'disaster disasters': 0.8176723718643188,
#  'disaster disaster': 1.0}

# %%
ttlsimsppc
# Out:
# {'de de': 0.9079835414886475,
#  'contaminación descarbonización': 0.8036044239997864,
#  'contaminación descontaminación': 0.9332984685897827,
#  'contaminación contaminantes': 0.8567338585853577,
#  'contaminación contaminación': 1.0,
#  'waste waste': 1.0,
#  'pollution pollution': 1.0}

# %%
ttlsimsct
# Out:
# {'la la': 0.939012348651886,
#  'transporte transporte': 1.0,
#  'no no': 0.9680165648460388,
#  'eléctricos eléctricos': 1.0,
#  'rail rail': 1.0,
#  'electric electric': 1.0,
#  'vehicle vehicles': 0.8584986925125122,
#  'transportation transportation': 1.0,
#  'battery battery': 1.0,
#  'charger battery': 0.8197756409645081,
#  'vehicle vehicle': 1.0,
#  'car car': 1.0,
#  'non non': 1.0,
#  'Elev domésticas': 0.8492071628570557,
#  'Elev mentoria': 0.8052674531936646,
#  'Elev norland': 0.8765970468521118,
#  'Elev trabalho': 0.8066929578781128,
#  'Elev equipamentos': 0.8798730373382568,
#  'Elev ambiental': 0.8465332388877869,
#  'Elev implantado': 0.8595749735832214,
#  'Elev desenvolvimento': 0.8341999053955078,
#  'Elev marabá': 0.8400039672851562,
#  'Elev capacidade': 0.8276458382606506,
#  'Elev gwh': 0.8765970468521118}

# %%
ttlsimsee
# Out:
# {'efficiency efficiency': 1.0, 'eficiência qualidade': 0.8311229348182678}

# %%
ttlsimsce
# Out:
# {'recycle recycling': 0.8278464674949646,
#  'reuse reuse': 1.0,
#  'circular circular': 1.0}

# %%
ttlsimsesml
# Out:
# {'. saneamiento': 0.8664849996566772,
#  '. orgánicos': 0.8785515427589417,
#  '. renovable': 0.8781610727310181,
#  '. energético': 0.8899020552635193,
#  '. responsable': 0.8858040571212769,
#  '. contaminante': 0.9003280997276306,
#  '. agrícola': 0.8843717575073242,
#  '. carbono': 0.8552056550979614,
#  '. compuertas': 0.8945333361625671,
#  '. electrificado': 0.9312004446983337,
#  '. naturales': 0.8490776419639587,
#  '. ambiental': 0.8732760548591614,
#  '. ordinarios': 0.891767144203186,
#  '. minero-energética': 0.9393861293792725,
#  '. desalinizadoras': 0.9288363456726074,
#  '. upme9': 1.0,
#  '. materiales': 0.8391605615615845,
#  '. sostenibles': 0.8721240758895874,
#  '. público': 0.8320438265800476,
#  '. 10mw': 1.0,
#  '. emisiones': 0.8010292053222656,
#  '. cantidad': 0.8216756582260132,
#  'Arboricultura acuicultura': 0.8038574457168579,
#  '. positivo': 0.8727385997772217,
#  '. colombiano': 0.9160950779914856,
#  '. ciclismo': 0.878090500831604,
#  'pesquerías pesquería': 0.8017709255218506,
#  '. comercial': 0.8960788249969482,
#  '. carga': 0.8002415895462036,
#  '. públicos': 0.8061527609825134,
#  '. infraestructura': 0.8884092569351196,
#  '. inteligentes': 0.8802396059036255,
#  '. r.l': 0.8423397541046143,
#  '. valorizables': 0.9034574627876282,
#  '. fiscalizaciones': 0.8523979187011719,
#  '. construcción': 0.8560630679130554,
#  '. huacas': 0.8966912627220154,
#  '. otorgados': 0.8606899976730347,
#  '. favorable': 0.891533613204956,
#  '. gbp': 1.0,
#  '. cdmx': 0.9229597449302673,
#  '. local': 0.8605929613113403,
#  '. financiadas': 0.8519583344459534,
#  '. período': 0.8331896662712097,
#  '. totalidad': 0.8684023022651672,
#  '. elegibles': 0.8690311312675476,
#  '. c.p': 0.9544176459312439,
#  '. climáticas': 0.85113126039505,
#  '. proyecto': 0.8189489841461182,
#  '. transporte': 0.8742616772651672,
#  '. tel': 0.8132050633430481,
#  '. méxico': 0.8943427205085754,
#  '. ambiente': 0.8363110423088074,
#  '. fósiles': 0.8289037346839905,
#  '. temprana': 0.8936052918434143,
#  '. generadas': 0.8607613444328308,
#  '. equivalentes': 0.9073979258537292,
#  '. humedales': 0.8677462339401245,
#  '. todavía': 0.9017109870910645,
#  '. continuación': 0.8725035190582275,
#  '. limpio': 0.8783907890319824,
#  '. ext': 0.81826251745224,
#  '. beneficiadas': 0.8821940422058105,
#  '. sefin': 1.0,
#  '. canales': 0.803642213344574,
#  '. combustibles': 0.878160834312439,
#  '. residual': 0.9217485785484314,
#  '. económicos': 0.8585679531097412,
#  '. edificaciones': 0.8335099816322327,
#  '. energéticas': 0.8682523369789124,
#  '. invernadero': 0.9198287725448608,
#  '. gaseosos': 0.8873090147972107,
#  '. residuales': 0.8812421560287476,
#  '. eléctricos': 0.8794209957122803,
#  '. energéticos': 0.8808454871177673,
#  '. masivo': 0.8817608952522278,
#  '. energía': 0.818902313709259,
#  '. emisión': 0.8207820653915405,
#  'food food': 1.0,
#  'agriculture agriculture': 1.0,
#  'agriculture agricultural': 0.898859441280365,
#  'forest forest': 1.0,
#  'land land': 0.8250224590301514,
#  'land “': 0.8367156982421875,
#  'forest forests': 0.8802252411842346,
#  'land lands': 0.8242226839065552,
#  'forestry forestry': 1.0,
#  'alimentares alimentos': 0.8313022255897522}

# %%
ttlsimsswwm
# Out:
# {'saneamiento mantenimiento': 0.8064507842063904,
#  '  potable': 1.0000001192092896,
#  'saneamiento abastecimiento': 0.8477514386177063,
#  'treatment treatment': 1.0,
#  'wastewater wastewater': 1.0,
#  'water water': 0.8583021759986877,
#  'sanitation sanitation': 0.8295572996139526,
#  'wastewater sewage': 0.8658150434494019,
#  'potable potable': 1.0}

# %%
ttlsimstabc
# Out:
# {'conservación aprovechamiento': 0.8383619785308838,
#  'conservación implementación': 0.8000835180282593,
#  'conservación construcción': 0.806158721446991,
#  'conservación utilización': 0.817090630531311,
#  'conservación restauración': 0.8449034690856934,
#  'conservación recuperación': 0.8293237686157227,
#  'terrestre terrestres': 0.8388893604278564,
#  'conservación realización': 0.8137819766998291,
#  'conservación gasificación': 0.8011845946311951,
#  'conservación reutilización': 0.8417978286743164,
#  'conservación observación': 0.8122673034667969,
#  'conservación reforestación': 0.8358405828475952,
#  'biodiversidad biodiversidad': 1.0,
#  'conservación mitigación': 0.8037376403808594,
#  'conservación contribución': 0.8010097742080688,
#  'biodiversity biodiversity': 1.0,
#  'conservation conservation': 1.0,
#  'biodiversity ecosystems': 0.8021105527877808,
#  'terrestrial terrestrial': 1.0}

# %%
ttlsimsgb
# Out:
# {'la la': 0.947020411491394,
#  'construcciones plantaciones': 0.8306095004081726,
#  'construcciones instalaciones': 0.807640016078949,
#  'y y': 0.9070735573768616,
#  'construcciones edificaciones': 0.9605708122253418,
#  'construcciones adecuaciones': 0.8131966590881348,
#  'construcciones construcciones': 1.0,
#  'buildings buildings': 0.8554772734642029,
#  'housing housing': 0.8488945960998535}

# %%
# write dataframes to csvfiles with versions in the filenames

dataframes = [results_df, table_df, UOP_df, UOP_Words_df, pred_train_rpts]
dfname_list = ['results_df', 'table_df', 'UOP_df', 'UOP_Words_df', 'pred_train_rpts']
csvname_list = ['results_csv', 'table_csv', 'UOP_csv', 'UOP_Words_csv', 'pred_train_rpts_csv']
filepath = '/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/'
extention = '.csv'
version = '5.0'


results_csv = results_df.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/results_csv_V5.csv')
table_csv = table_df.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/table_csv_V5.csv')
UOP_csv = UOP_df.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/UOP_csv_V5.csv')
UOP_Words_csv = UOP_Words_df.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/UOP_Words_csv_V5.csv')
pred_train_rpts_csv = pred_train_rpts.to_csv(path_or_buf='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/pred_train_rpts_V5.csv')
