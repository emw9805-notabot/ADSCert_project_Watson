# %%
import pandas as pd

test_data = pd.read_csv('test_data_with_measures.csv')
test_df = pd.DataFrame(test_data)
test_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9604 entries, 0 to 9603
# Data columns (total 33 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   comp_test                        9604 non-null   str
#  1   src_table                        9604 non-null   str
#  2   Bond handle                      9604 non-null   str
#  3   Project handle                   7879 non-null   str
#  4   Unit                             6642 non-null   str
#  5   Indicator                        6642 non-null   str
#  6   Nomenclature                     9442 non-null   str
#  7   Category                         9442 non-null   str
#  8   Subcategory                      2998 non-null   str
#  9   Location                         8425 non-null   str
#  10  Issuance date (date)             62 non-null     str
#  11  Maturity date (date)             62 non-null     str
# ...
