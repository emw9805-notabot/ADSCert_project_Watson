# %% [markdown]
# SUMMARY INFO
# numerical data: volume issued volume raised
#
# dimension data: stock exchange
# id data: bond handle
#
# Missing data: stock exchange
#
#
# Outliers:

# %% [markdown]
# ALIGN WITH QUAL RESEARCH
#  - CBI
#  - META-ANALYSIS

# %% [markdown]
# how much info does this add over bonds, given the row count is only 11 greater
#
# volume offered & volume raised
# also stock exchange

# %%
import pandas as pd
gbtp_tranches_data = pd.read_csv('tranches.csv')
gbtp_tranches_df = pd.DataFrame(gbtp_tranches_data)
gbtp_tranches_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Bond handle                         281 non-null    str
#  1   Bond name                           281 non-null    str
#  2   Market                              281 non-null    str
#  3   Stock exchange                      156 non-null    str
#  4   Tranche currency                    281 non-null    str
#  5   Volume offered in tranche currency  281 non-null    float64
#  6   Volume raised in tranche currency   281 non-null    float64
#  7   Bond currency                       281 non-null    str
#  8   Volume raised in bond currency      281 non-null    float64
#  9   Volume raised in USD                281 non-null    int64
# dtypes: float64(3), int64(1), str(6)
# memory usage: 22.1 KB

# %%
gbtp_tranches_df.describe()
# Out:
#        Volume offered in tranche currency  Volume raised in tranche currency  \
# count                        2.810000e+02                       2.810000e+02
# mean                         2.094212e+10                       2.094182e+10
# std                          9.609696e+10                       9.609703e+10
# min                          2.000000e+02                       2.000000e+02
# 25%                          3.087000e+07                       3.000000e+07
# 50%                          2.150000e+08                       2.150000e+08
# 75%                          7.500000e+08                       7.500000e+08
# max                          7.499998e+11                       7.499998e+11
#
#        Volume raised in bond currency  Volume raised in USD
# count                    2.810000e+02          2.810000e+02
# mean                     2.094182e+10          1.552543e+08
# std                      9.609703e+10          2.698990e+08
# ...

# %%
gbtp_tranches_df.head()
# Out:
#                         Bond handle                                Bond name  \
# 0  ee7a68239dbe4664adad596c19403c93  Suzano Papel e Celulose Green Bond 2026
# 1  ee7a68239dbe4664adad596c19403c93  Suzano Papel e Celulose Green Bond 2026
# 2  fe8a86a4318f49fb850f1dfa256f263b                              GCDMXCB 16V
# 3  cffe109b8d59400dbf3b62d9e36c0d76                              GCDMXCB 17X
# 4  0f91b88562524743ad5ecf105cddab89        Banco Nacional de Costa Rica 2021
#
#           Market Stock exchange Tranche currency  \
# 0  United States            NaN              USD
# 1  United States            NaN              USD
# 2         Mexico            NaN              MXN
# 3         Mexico            NaN              MXN
# 4  United States            NaN              USD
#
#    Volume offered in tranche currency  Volume raised in tranche currency  \
# 0                        5.000000e+08                       5.000000e+08
# ...

# %%
gbtp_tranches_df.isnull().sum()
# Out:
# Bond handle                             0
# Bond name                               0
# Market                                  0
# Stock exchange                        125
# Tranche currency                        0
# Volume offered in tranche currency      0
# Volume raised in tranche currency       0
# Bond currency                           0
# Volume raised in bond currency          0
# Volume raised in USD                    0
# dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns


fig, ax = plt.subplots()
fig.set_size_inches(12,9)

sns.swarmplot(x='Tranche currency', y='Volume raised in USD', data= gbtp_tranches_df, hue='Stock exchange', size=10)
plt.xticks(rotation=-45)
# Out:
# /Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 55.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/.venv/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 62.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
