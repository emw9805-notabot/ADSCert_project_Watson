# %% [markdown]
# NLP for Case Study 1 framework

# %%
pip install TIKA
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
from tika import parser
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/tika/__init__.py:20: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
path = "/Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/inscope framework reports/Coca-Cola_FEMSA_Green_Bond_Framework.pdf"

# The from_file() function of tika helps us to load the content of the document. (take ca. 30 sec)
# report = parser.from_file(path)

report_ccf_framework = parser.from_file(path)

# %%
print(report_ccf_framework["content"])
# Out:
# U P D A T E D  A S  O F  A U G U S T  2 0 2 0
#
# Green Bond
# F R A M E W O R K
#
#
#
# Contents
# 01 I N T R O D U C T I O N
#
# 02 A P P R O A C H  T O  S U S T A I N A B I L I T Y
#
# 03 R A T I O N A L E  F O R  I S S U A N C E
#
# 4.1
#
# 4.2
#
# 4.3
#
# 4.4
#
# U S E  O F  P R O C E E D S
#
# P R O C E S S  F O R  P R O J E C T  E V A L U A T I O N  A N D  S E L E C T I O N
#
# M A N A G E M E N T  O F  P R O C E E D S
#
# R E P O R T I N G
#
# 04 A L I G N M E N T  W I T H  G R E E N  B O N D  P R I N C I P L E S ,  2 0 1 8
#
# 5.1
#
# 5.2
#
# S E C O N D  P A R T Y  O P I N I O N
#
# A S S U R A N C E
#
# 05 E X T E R N A L  R E V I E W
#
# C O C A - C O L A  F E M S A
#
# 2
#
# G R E E N  B O N D  F R A M E W O R K
#
#
#
# Coca-Cola FEMSA is the largest franchise bottler
# of Coca-Cola trademark beverages in the world by
# sales volume. We operate 49 bottling plants and
# serve nearly 2 million points of sales through 268
# ...

# %%
nlp = spacy.load('en_core_web_sm')
about_doc = nlp(report_ccf_framework["content"])

# %%
sequences_FW = list(map(str, about_doc.sents))
sequences_FW
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nU P D A T E D  A S  O F  A U G U S T  2 0 2 0\n\nGreen Bond\nF R A M E W O R K\n\n\n\nContents\n01 I N T R O D U C T I O N\n\n',
#  '02 A P P R O',
#  'A C H  T O  S U S T A I N A B I L I T Y\n\n03 R A T',
#  'I O N A L E  F O R  I S S U A N C E\n\n4.1\n\n4.2\n\n4.3\n\n4.4\n\nU S E  O F  P R O C E E D S\n\nP R O C E S S  F O R  P R O J E C T  E V A L U A T',
#  'I O N  A N D  S E L E C T',
#  'I O N\n\nM A N A G E M E N T  O F  P R O C E E D S\n\nR E P O R T',
#  'I N G\n\n04',
#  'A L',
#  'I G N M E N T  W I T H  G R E E N  B',
#  'O N D  P R I N C I P L E S ,  2 0 1 8\n\n5.1\n\n5.2\n\nS E C O N D  P A R T Y  O P',
#  'I N I O N\n\nA S S U R A N C E\n\n05 E X T E R N A L  R E V I E W\n\nC O C A - C O L A  F E M S A\n\n2\n\nG R E E N  B',
#  'O N D  F R A M E W O R K\n\n\n\nCoca-Cola FEMSA is the largest franchise bottler \nof Coca-Cola trademark beverages in the world by \nsales volume.',
# ...

# %%
path = "/Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/inscope framework reports/in scope Bond reports/bono-verde-ingles.pdf"

# The from_file() function of tika helps us to load the content of the document. (take ca. 30 sec)
# report = parser.from_file(path)

report_ccf_bond_alloc = parser.from_file(path)

# %%
print(report_ccf_bond_alloc["content"])
# Out:
# COCA-COLA FEMSA
#
# GREEN BOND
# REPORT 2022
#
#
#
# SUSTAINABLE FINANCING
# Our approach to sustainable financing
# enables us to maximize our positive
# impact by publicly aligning our finance
# strategy with the achievement of our
# environmental and social ambitions,
# while contributing to the United Nations
# Sustainable Development Goals. We have
# leveraged our investments with financial
# instruments that allow us to direct our
# resources appropriately to mitigate
# risk, increase positive impact, and align
# incentives within the company with our
# ESG objectives.
#
# Green Bond Progress Report
# Aligned with this approach and our sustainability strategy, we
# issued our first-ever green bond in September 2020, valued
# at US$705 million, at the time the largest for a Latin Ameri-
# can corporation and a first for the Coca-Cola System.
#
# As of December 31, 2022, we had allocated US$664.87 mil-
# lion of green bond net proceeds to finance or refinance eligi-
# ...

# %%
pip install pdfplumber
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber

# %%
import pdfplumber

with pdfplumber.open("/Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/inscope framework reports/Coca-Cola_FEMSA_Green_Bond_Framework.pdf") as pdf:
    UoP_page1 = pdf.pages[7]
    print(UoP_page1.extract_text())
    # UOP_info = UoP_page1.extract_text()
    # print(UOP_info)
# Out:
# COCA-COLA FEMSA GREEN BOND FRAMEWORK
# 4 For more information on the Sustainable Development Goals, see https://sdgs.un.org/goals
# The eligibility criteria are outlined below:
# GBP Eligible Project Category Eligibility Criteria and Example Projects SDG Alignment4
# Expenditures related to procurement and usage of climate change module software that
# Climate Change Adaptation will allow us to accurately measure our carbon footprint in a systematized manner and track
# progress against our science-based targets.
# Expenditures related to our own- and third-party transportation fleet such as:
# Clean and Mass
# • Fully electric trucks and utility vehicles.
# Transportation
# • Electric vehicle infrastructure including charging stations.
# Expenditures related to energy-efficiency projects including equipment, systems, operational
# improvements and maintenance. Examples include:
# • Expenditures to improve and maintain energy efficiency including as it relates to heating,
# ...

# %%
with pdfplumber.open("/Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/inscope framework reports/Coca-Cola_FEMSA_Green_Bond_Framework.pdf") as pdf:
    UoP_page1 = pdf.pages[6]
    UoP_page2 = pdf.pages[7]
    UoP_page3 = pdf.pages[8]

# %%
renewable_energy_instances = UoP_page1.search('Renewable Energy')
len(renewable_energy_instances)
# Out:
# 1

# %%
nlp = spacy.load('en_core_web_sm')
about_doc = nlp(UOP_info)

# %%
sequences_UoP = list(map(str, about_doc.sents))
sequences_UoP
# Out:
# ['COCA-COLA FEMSA GREEN BOND FRAMEWORK\n4 For more information on the Sustainable Development Goals, see https://sdgs.un.org/goals\nThe eligibility criteria are outlined below:\nGBP Eligible Project Category Eligibility Criteria and Example Projects SDG Alignment4\nExpenditures related to procurement and usage of climate change module software that\nClimate Change Adaptation will allow us to accurately measure our carbon footprint in a systematized manner and track\nprogress against our science-based targets.\n',
#  'Expenditures related to our own- and third-party transportation fleet such as:\nClean and Mass\n• Fully electric trucks and utility vehicles.\n',
#  'Transportation\n• Electric vehicle infrastructure including charging stations.\n',
#  'Expenditures related to energy-efficiency projects including equipment, systems, operational\nimprovements and maintenance.',
# ...

# %%
type(pdf)
# Out:
# pdfplumber.pdf.PDF

# %%
pdf.metadata
# Out:
# {'CreationDate': "D:20200824103531-05'00'",
#  'Creator': 'Adobe InDesign 15.1 (Macintosh)',
#  'ModDate': "D:20200824103545-05'00'",
#  'Producer': 'Adobe PDF Library 15.0',
#  'Trapped': 'False'}

# %%
type(UoP_page1)
# Out:
# pdfplumber.page.Page

# %%
print(UoP_page1.page_number)
print(UoP_page1.width)
print(UoP_page1.height)
print(UoP_page1.objects)
print(UoP_page1.chars)
print(UoP_page1.lines)
print(UoP_page1.rects)
print(UoP_page1.curves)
print(UoP_page1.images)
# Out:
# 8
# 1366.0
# 768.0
# ...

# %%
UoP_page1.rects
# Out:
# [{'x0': 144.95,
#   'y0': 622.571,
#   'x1': 366.5,
#   'y1': 654.381,
#   'width': 221.55,
#   'height': 31.809999999999945,
#   'pts': [(144.95, 113.61900000000003),
#    (366.5, 113.61900000000003),
#    (366.5, 145.42899999999997),
#    (144.95, 145.42899999999997)],
#   'linewidth': 0,
#   'stroke': False,
#   'fill': True,
#   'evenodd': False,
#   'stroking_color': 0,
#   'non_stroking_color': (0.455, 0.667, 0.314),
#   'mcid': None,
#   'tag': None,
#   'object_type': 'rect',
#   'page_number': 8,
#   'path': [('m', (144.95, 113.61900000000003)),
#    ('l', (366.5, 113.61900000000003)),
#    ('l', (366.5, 145.42899999999997)),
#    ('l', (144.95, 145.42899999999997)),
#    ('h',)],
#   'dash': None,
#   'top': 113.61900000000003,
#   'bottom': 145.42899999999997,
#   'doctop': 5489.619},
#  {'x0': 366.5,
#   'y0': 622.571,
#   'x1': 967.85,
#   'y1': 654.381,
#   'width': 601.35,
#   'height': 31.809999999999945,
#   'pts': [(366.5, 113.61900000000003),
# ...

# %%
table = UoP_page1.extract_table()
for row in table:
    print(row)
# Out:
# ['GBP Eligible Project Category', 'Eligibility Criteria and Example Projects', 'SDG Alignment4']

# %%
im = UoP_page1.to_image()
im.debug_tablefinder()

# %%
im.show()

# %%
with pdfplumber.open("/Users/elisabethwatson/Birkbeck/PGC ADS/Module 3 Project/Datasets/GBTP 260201/inscope framework reports/in scope Bond reports/bono-verde-ingles.pdf") as pdf:
    GB_Alloc1 = pdf.pages[1]
    print(GB_Alloc1.extract_text())
# Out:
# Green Bond Allocation
# As of December 31, 2022, Coca-Cola FEMSA had allocated
# US$664.87 million of green bond net proceeds to projects
# supporting circular economy, water stewardship, and
# climate action.
# SUSTAINABLE FINANCING
# Our approach to sustainable financing
# enables us to maximize our positive Green Bond Progress Report
# impact by publicly aligning our finance Aligned with this approach and our sustainability strategy, we
# strategy with the achievement of our issued our first-ever green bond in September 2020, valued
# environmental and social ambitions, at US$705 million, at the time the largest for a Latin Ameri-
# while contributing to the United Nations can corporation and a first for the Coca-Cola System.
# Sustainable Development Goals. We have
# leveraged our investments with financial As of December 31, 2022, we had allocated US$664.87 mil-
# instruments that allow us to direct our lion of green bond net proceeds to finance or refinance eligi-
# ...

# %%
table = GB_Alloc1.extract_table()
for row in table:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 table = GB_Alloc1.extract_table()
# ----> 2 for row in table:
#       3     print(row)
#
# TypeError: 'NoneType' object is not iterable

# %%
im = GB_Alloc1.to_image()
im.debug_tablefinder()
