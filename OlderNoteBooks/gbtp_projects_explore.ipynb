# %% [markdown]
# SUMMARY INFO
# numerical data: represented projects, logitude & latitude
# class data: nomenclature, refinancing(bool)
# dimension data: host orgn, category, subcategory, location
# id data: bond handle, project handle and name
#
#
# Missing data: see box below
#
# Dimesion data: reviewed in excel to get a basic understanding of the data
#
#
# Outliers:

# %% [markdown]
# ALIGN WITH QUAL RESEARCH
#  - CBI
#  - META-ANALYSIS

# %% [markdown]
# mising locations and description data - how useful are the records without this?

# %%
import pandas as pd
gbtp_projects_data = pd.read_csv('projects.csv')
gbtp_projects_df = pd.DataFrame(gbtp_projects_data)
gbtp_projects_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1955 entries, 0 to 1954
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Bond handle             1955 non-null   str
#  1   Bond name               1955 non-null   str
#  2   Project handle          1955 non-null   str
#  3   Project link            1955 non-null   str
#  4   Parent project handle   102 non-null    str
#  5   Parent project link     102 non-null    str
#  6   Latitude                837 non-null    float64
#  7   Longitude               837 non-null    float64
#  8   Location                1477 non-null   str
#  9   Refinancing             1955 non-null   str
#  10  Cofinancing percentage  1875 non-null   float64
#  11  Host organisation       1955 non-null   str
#  12  Represented projects    1955 non-null   int64
#  13  Nomenclature            1944 non-null   str
#  14  Category                1944 non-null   str
# ...

# %%
gbtp_projects_df.describe()
# Out:
#            Latitude     Longitude  Cofinancing percentage  \
# count  8.370000e+02  8.370000e+02             1875.000000
# mean  -6.457773e+05 -1.370316e+06               70.442133
# std    3.694239e+06  7.818307e+06               35.622446
# min   -2.331192e+07 -4.809608e+07                0.000000
# 25%   -3.347271e+01 -7.239668e+01               41.000000
# 50%   -2.266384e+01 -5.251570e+01               92.000000
# 75%   -4.194588e+00 -4.485016e+01              100.000000
# max    2.332126e+01  1.177276e+02              100.000000
#
#        Represented projects
# count           1955.000000
# mean               0.040921
# std                0.439087
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               10.000000

# %%
gbtp_projects_df.head()
# Out:
#                         Bond handle                     Bond name  \
# 0  9fc875791e3143a1bb3f864a304e8185  Green Bond 2017 - Davivienda
# 1  9fc875791e3143a1bb3f864a304e8185  Green Bond 2017 - Davivienda
# 2  9fc875791e3143a1bb3f864a304e8185  Green Bond 2017 - Davivienda
# 3  9fc875791e3143a1bb3f864a304e8185  Green Bond 2017 - Davivienda
# 4  3e001fbc60b6457dbbb4e67ee69152c0                      BAGUA-AE
#
#                      Project handle  \
# 0  68a331e850c4400991e7f702fd521645
# 1  68a331e850c4400991e7f702fd521645
# 2  68a331e850c4400991e7f702fd521645
# 3  68a331e850c4400991e7f702fd521645
# 4  633847476b4a4f3699cf8f6e71adb550
#
#                                         Project link Parent project handle  \
# 0  https://www.greenbondtransparency.com/project-...                   NaN
# 1  https://www.greenbondtransparency.com/project-...                   NaN
# 2  https://www.greenbondtransparency.com/project-...                   NaN
# ...

# %%
gbtp_projects_df.isnull().sum()
# Out:
# Bond handle                  0
# Bond name                    0
# Project handle               0
# Project link                 0
# Parent project handle     1853
# Parent project link       1853
# Latitude                  1118
# Longitude                 1118
# Location                   478
# Refinancing                  0
# Cofinancing percentage      80
# Host organisation            0
# Represented projects         0
# Nomenclature                11
# Category                    11
# Subcategory               1447
# Project description        466
# dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns


fig, ax = plt.subplots()
fig.set_size_inches(12,9)

sns.countplot(x='Nomenclature', data= gbtp_projects_df)
plt.xticks(rotation=-45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'ISO'),
#   Text(1, 0, 'EU Taxonomy Green Bonds Standard'),
#   Text(2, 0, 'ICMA Green Bonds Principles Project Categories'),
#   Text(3, 0, 'Climate Bonds Initiative Project Classification')])

# %%
gbtp_projects_df.groupby('Location').count().filter(['Bond handle'])

# also work out sort
# Out:
#                                 Bond handle
# Location
# ATACAMA                                   2
# ATACAMA-COQUIMBO                         10
# ATACAMA-COQUIMBO-VALPARAISO-RM            4
# Alajuela Province                        33
# Almino Afonso - RN                        3
# ...                                     ...
# Vitória do Palmar                         5
# Western Australia                         4
# Yucatan Peninsula                         8
# Yucatán                                   3
# Zacatecas                                 3
#
# [178 rows x 1 columns]

# %%
gbtp_projects_df.groupby('Category').count().filter(['Bond handle'])
# Out:
#                                       Bond handle
# Category
# Agriculture                                    34
# Appliances                                     32
# Bioenergy                                      17
# Climate observation                             1
# Commercial                                     56
# Commercial Forestry                            16
# Data hubs                                       1
# Distribution                                    5
# District heating                                1
# Early warning systems                           2
# Ecosystem Conservation & Restoration           24
# Electric                                        8
# Energy storage                                  1
# Flood defence                                  20
# Flooding mitigation                            19
# Forestry                                       22
# Freight Rail                                    1
# General                                        22
# ...
