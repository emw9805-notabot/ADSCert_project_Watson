# %%
import pandas as pd

# %%
UOPWords_output = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/UOP_Words_csv_V5.csv')
UOPW_out_df = pd.DataFrame(UOPWords_output)
test1 = UOPW_out_df['renewable_energy'].to_list()
print(test1)
test2 = UOPW_out_df['re_scores'].to_list()
print(test2)
# Out:
# ["dict_keys(['generation generation', 'power power', 'renewable renewable', 'solar solar', 'transmission transmission'])", "dict_keys(['renewable renewable', 'wind wind', 'solar solar', 'biomass biomass'])", "dict_keys(['biomass biomass', 'power power', 'renewable renewable', 'solar solar', 'hydropower hydropower', 'hydroelectric hydropower', 'wind wind'])", "dict_keys(['grid grid', 'renewable renewable', 'biofuel biofuel', 'transmission transmission', 'wind wind', 'power power', 'solar solar', 'hydropower hydropower', 'hydroelectric hydropower', 'generation generation', 'hydrogen hydrogen'])", "dict_keys(['renewable renewable', 'wind wind', 'solar solar'])", "dict_keys(['generation generation', 'biomass biomass', 'biofuel biofuel'])", "dict_keys(['generation generation', 'power power', 'wind wind', 'renewable renewable', 'transmission transmission', 'grid grid'])", "dict_keys(['generation generation', 'power power', 'renewable renewable', 'wind wind', 'solar solar', 'transmission tr
# ...
