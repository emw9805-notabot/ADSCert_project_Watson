# %%
import pandas as pd

# %%
simDicts_output = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/pred_train_rpts_VDict.csv')
simDicts = pd.DataFrame(simDicts_output)
simDicts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            3 non-null      int64
#  1   pdfname               3 non-null      str
#  2   nlp_path              3 non-null      str
#  3   language              3 non-null      str
#  4   similarity_threshold  3 non-null      float64
#  5   cleanup_threshold     3 non-null      float64
#  6   ES_0_percent          3 non-null      bool
#  7   ES_100_percent        3 non-null      bool
#  8   ES_partial            3 non-null      bool
#  9   number_of_cats        3 non-null      int64
#  10  simsre                3 non-null      str
#  11  resimScores           3 non-null      str
# dtypes: bool(3), float64(2), int64(2), str(5)
# memory usage: 985.0 bytes

# %%
simDicts['simsre'].iloc[0]
# Out:
# "{'generation generation': 0.8221270442008972, 'power power': 1.0, 'renewable renewable': 1.0, 'solar solar': 1.0, 'transmission transmission': 1.0}"

# %%
simDicts_output = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/sims_dicts_V5.csv')
simDicts = pd.DataFrame(simDicts_output)
simDicts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1 non-null      int64
#  1   ttlsimScores_cln  1 non-null      str
#  2   ttlresimScores    1 non-null      str
#  3   ttlsimsre         1 non-null      str
#  4   ttlsimsee         1 non-null      str
#  5   ttlsimsppc        1 non-null      str
#  6   ttlsimsesml       1 non-null      str
#  7   ttlsimstabc       1 non-null      str
#  8   ttlsimsct         1 non-null      str
#  9   ttlsimscca        1 non-null      str
#  10  ttlsimsce         1 non-null      str
#  11  ttlsimsswwm       1 non-null      str
#  12  ttlsimsgb         1 non-null      str
#  13  V5_th_list        1 non-null      str
# dtypes: int64(1), str(13)
# memory usage: 11.5 KB

# %%
simDicts['V5_th_list'].to_list()
# Out:
# ["['cleanup', 0.7338055670261383, np.float64(0.6936290115118027), 're_tbl', 0.9304536283016205, np.float64(0.8403543829917908), 're_uop', 0.885119616985321, np.float64(0.825370728969574), 'ee_uop', 0.9155614674091339, np.float64(0.8733422011137009), 'cca_uop', 0.8254500031471252, np.float64(0.8100579977035522), 'ppc_uop', 0.9332984685897827, np.float64(0.8823587000370026), 'tabc_uop', 0.8293237686157227, np.float64(0.8049481809139252), 'esml_uop', 0.8781256675720215, np.float64(0.8415449559688568), 'ct_uop', 0.8782350420951843, np.float64(0.8449009209871292), 'ce_uop', 1.0, np.float64(0.9139232337474823), 'swwm_uop', 0.8658150434494019, np.float64(0.8477514386177063), 'gb_uop', 0.8554772734642029, np.float64(0.8306095004081726)]"]

# %%
meds = [0.9304536283016205, 0.885119616985321, 0.9155614674091339, 0.8254500031471252, 0.9332984685897827, 0.8293237686157227, 0.8781256675720215, 0.8782350420951843, 1.0, 0.8658150434494019, 0.8554772734642029]
cent = [0.8403543829917908, 0.825370728969574, 0.8733422011137009, 0.8100579977035522, 0.8823587000370026, 0.8049481809139252, 0.8415449559688568, 0.8449009209871292, 0.9139232337474823, 0.8477514386177063, 0.8306095004081726]

columns = ['meds', 'cent']
stats_df = pd.DataFrame()
stats_df['meds'] = meds
stats_df['cent'] = cent
stats_df.describe()
# Out:
#             meds       cent
# count  11.000000  11.000000
# mean    0.890624   0.846833
# std     0.051175   0.032204
# min     0.825450   0.804948
# 25%     0.860646   0.827990
# 50%     0.878235   0.841545
# 75%     0.923008   0.860547
# max     1.000000   0.913923

# %%
simDicts['ttlsimScores_cln'].to_dict()
# Out:
# {0: "{'pequeñas centrales hidroeléctricas hidroelectricidad': 0.7128672003746033, 'pequeñas centrales hidroeléctricas construcciones': 0.7090030908584595, 'centrales eólicas (solo terrestres) cuadrícula (sólo)': 0.8724079728126526, 'proyecto de energías renovables (energía hidroeléctrica – contribución a mitigación del cambio climático) de alimentos': 0.6540133953094482, 'energy efficiency renewable': 0.665412187576294, 'energy efficiency efficiency': 0.9004887938499451, 'access to basic housing housing': 0.6902390718460083, 'renewable energy renewable': 0.9201155304908752, 'renewable energy solar': 0.7037988305091858, 'access to affordable housing housing': 0.7369170188903809, 'green buildings (ecological buildings) buildings': 0.8016582131385803, 'natural resources, use of land and protected marine areas land': 0.6691650152206421, 'food security food': 0.7798810005187988, 'water management water': 0.8119471073150635, 'potable water supply water': 0.8469440937042236, 'potable water 
# ...

# %%
simDicts['ttlresimScores'].to_dict()
# Out:
# {0: "{'hidroelectricidad': 0.8112889528274536, 'cuadrícula (sólo)': 0.9524129033088684, 'bioenergía': 0.8198481798171997, 'Hidroeléctrico': 0.8471897840499878, 'renewable': 1.0, 'transmissão': 1.0, 'energia': 1.0, 'energia hidráulica': 0.9084943532943726}"}

# %%
simDicts_output_v7 = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/sims_dicts_V7.csv')
simDicts_v7 = pd.DataFrame(simDicts_output)
simDicts_v7.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1 non-null      int64
#  1   ttlsimScores_cln  1 non-null      str
#  2   ttlresimScores    1 non-null      str
#  3   ttlsimsre         1 non-null      str
#  4   ttlsimsee         1 non-null      str
#  5   ttlsimsppc        1 non-null      str
#  6   ttlsimsesml       1 non-null      str
#  7   ttlsimstabc       1 non-null      str
#  8   ttlsimsct         1 non-null      str
#  9   ttlsimscca        1 non-null      str
#  10  ttlsimsce         1 non-null      str
#  11  ttlsimsswwm       1 non-null      str
#  12  ttlsimsgb         1 non-null      str
#  13  V5_th_list        1 non-null      str
# dtypes: int64(1), str(13)
# memory usage: 11.5 KB

# %%
simDicts_output = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames_2ndPass/sims_dicts_V6.csv')
simDicts = pd.DataFrame(simDicts_output)
simDicts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1 non-null      int64
#  1   ttlsimScores_cln  1 non-null      str
#  2   ttlresimScores    1 non-null      str
#  3   ttlsimsre         1 non-null      str
#  4   ttlsimsee         1 non-null      str
#  5   ttlsimsppc        1 non-null      str
#  6   ttlsimsesml       1 non-null      str
#  7   ttlsimstabc       1 non-null      str
#  8   ttlsimsct         1 non-null      str
#  9   ttlsimscca        1 non-null      str
#  10  ttlsimsce         1 non-null      str
#  11  ttlsimsswwm       1 non-null      str
#  12  ttlsimsgb         1 non-null      str
#  13  V6_th_list        1 non-null      str
# dtypes: int64(1), str(13)
# memory usage: 48.5 KB

# %%
simDicts['ttlsimScores_cln'].to_list()
# Out:
# ["{'renewable energy renewable': 0.9201155304908752, 'afof rdable housing housing': 1.0, 'energy efficiency efficiency': 0.9004887938499451, 'sanitation sanitation': 1.0, 'energia renovável energia': 0.9140269160270691}"]

# %%
simDicts['ttlresimScores'].to_list()
# Out:
# ["{'renewable': 1.0, 'energia': 1.0, 'bioenergia': 0.7116448283195496, 'energia hidráulica': 0.9084943532943726, 'biocombustível': 0.7073158025741577}"]
