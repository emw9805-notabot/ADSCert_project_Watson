# %% [markdown]
# ### Create confusion matrix and box plots for predictions from nlp adn ground truth data

# %%
import pandas as pd

# %%
gt_train_rpts = pd.read_excel(io='/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/bondsAllocsJune7.xlsx', sheet_name='ground_truth_train', dtype={'pdfname': str, "gt_source": str, "ES_0_percent": bool, "ES_100_percent": bool, "ES_partial": bool, "number_of_cats": int})
gt_train_df = pd.DataFrame(gt_train_rpts)
gt_train_df
# Out:
#                                               pdfname         gt_source  \
# 0                 Bci_Sustainable_Financing_Framework            manual
# 1                               Bono_Azul_-_Framework            manual
# 2                   Bono_Verde_de_Bancoldex_Framework            manual
# 3   BTG_Pactual_Green,_Social_and_Sustainable_Fina...            manual
# 4                 BTG_Sustainable_Financing_Framework            manual
# 5                          CABEI_Green_Bond_Framework            manual
# 6                           CADU_GREEN_BOND_FRAMEWORK            manual
# 7                           CAFs_GREEN_BOND_FRAMEWORK            manual
# 8                               Cartilla_Bonos_Verdes            manual
# 9                    Chile_Sustainable_Bond_Framework            manual
# 10                          CIFI_Green_Bond_Framework            manual
# 11  Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...  alloc data table
# 12               Coca-Cola_FEMSA_Green_Bond_Framework  alloc data table
# 13               EGE_Haina_Green_Securities_Framework            manual
# 14                FS_Green_Bond_Framework_-_July_2021            manual
# 15            FS_Green_Bond_Framework_-_November_2020            manual
# 16                       Genneia_Green_Bond_Framework            manual
# 17                  Genneia_Green_Financing_Framework            manual
# 18                     Green_Bond_Financing_Framework            manual
# 19                               Green_Bond_Framework            manual
# 20            Green_Bond_Framework_of_Banco_Guayaquil            manual
# 21                   Green_Bonds_Framework_Athon_2020  alloc data table
# 22                 Green_Finance_Framework_Interchile            manual
# 23      Green_social_bond_framework_series_ad_ae_2019  alloc data table
# 24                     ILAP_Green_Financing_Framework            manual
# 25                                  ISA_CTM_FRAMEWORK            manual
# 26                     Marco_de_Gestion_de_Bono_Verde            manual
# 27                Marco_de_referencia_Bono_Verde_BPDC            manual
# 28  Marco_de_referencia_de_bono_verde_Coopeguanaca...            manual
# 29  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...            manual
# 30  Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...            manual
# 31  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...            manual
# 32                 Nacional_Financiera_Green_Bond_MXN            manual
# 33                 Nacional_Financiera_Green_Bond_USD            manual
# 34  Reference_Framework_Of_Green_Social_Sustainabl...            manual
# 35                       Sicredi_Green_Bond_Framework            manual
# 36                    SONDA_S_A__GREEN_BOND_FRAMEWORK  alloc data table
#
#     ES_0_percent  ES_100_percent  ES_partial  number_of_cats
# 0          False           False        True               6
# 1           True           False       False               0
# 2          False           False        True               5
# 3          False           False        True               7
# 4          False           False        True              13
# 5          False           False        True               4
# 6           True           False       False               0
# 7          False           False        True               6
# 8          False           False        True               8
# 9          False           False        True              17
# 10         False           False        True               3
# 11         False            True       False               0
# 12         False           False        True               3
# 13         False            True       False               0
# 14         False           False        True               2
# 15         False           False        True               2
# 16         False            True       False               0
# 17         False            True       False               0
# 18          True           False       False               0
# 19         False            True       False               0
# 20         False           False        True               4
# 21         False            True       False               0
# 22         False           False        True               2
# 23         False           False        True               2
# 24         False            True       False               0
# 25         False           False        True               2
# 26         False            True       False               0
# 27         False           False        True               8
# 28         False            True       False               0
# 29         False           False        True               8
# 30         False           False        True               8
# 31         False           False        True              11
# 32         False            True       False               0
# 33         False            True       False               0
# 34          True           False       False               0
# 35         False           False        True               2
# 36          True           False       False               0

# %%
pred_train_rpts = pd.read_csv('/Users/elisabethwatson/Documents/GitHub/ADSCert_project_Watson/Output_DataFrames/pred_train_rpts_V4.csv')
pred_train_df = pd.DataFrame(pred_train_rpts)
pred_train_df
# Out:
#     Unnamed: 0                                            pdfname  \
# 0            0  Climate_Bond_Framework_of_E1_SUBHOLDING_S_A__i...
# 1            1                   Chile_Sustainable_Bond_Framework
# 2            2                  Genneia_Green_Financing_Framework
# 3            3  Marco_de_Uso_de_Fondo_para_la_Emision_de_Bonos...
# 4            4                               Green_Bond_Framework
# 5            5                               Green_Bond_Framework
# 6            6                   Green_Bonds_Framework_Athon_2020
# 7            7                              Cartilla_Bonos_Verdes
# 8            8                              Bono_Azul_-_Framework
# 9            9  Marco_de_referencia_de_bono_verde_Coopeguanaca...
# 10          10  Marco_de_Referencia_del_Bono_Verde_de_la_Ciuda...
# 11          11                 Nacional_Financiera_Green_Bond_MXN
# 12          12                    Marco_de_Gestión_de_Bono_Verde
# 13          13                  Bono_Verde_de_Bancoldex_Framework
# 14          14      Green_social_bond_framework_series_ad_ae_2019
# 15          15                                  ISA_CTM_FRAMEWORK
# 16          16                    SONDA_S_A__GREEN_BOND_FRAMEWORK
# 17          17                          CIFI_Green_Bond_Framework
# 18          18                BTG_Sustainable_Financing_Framework
# 19          19                         CABEI_Green_Bond_Framework
# 20          20                       Genneia_Green_Bond_Framework
# 21          21                FS_Green_Bond_Framework_-_July_2021
# 22          22                          CAFs_GREEN_BOND_FRAMEWORK
# 23          23  BTG_Pactual_Green,_Social_and_Sustainable_Fina...
# 24          24                     ILAP_Green_Financing_Framework
# 25          25               EGE_Haina_Green_Securities_Framework
# 26          26                          CADU_GREEN_BOND_FRAMEWORK
# 27          27                Bci_Sustainable_Financing_Framework
# 28          28            FS_Green_Bond_Framework_-_November_2020
# 29          29                       Sicredi_Green_Bond_Framework
# 30          30                 Nacional_Financiera_Green_Bond_USD
# 31          31                     Green_Bond_Financing_Framework
# 32          32            Green_Bond_Framework_of_Banco_Guayaquil
# 33          33  Marco_de_referencia_de_Bonos_Verdes_Soberanos_...
# 34          34                 Green_Finance_Framework_Interchile
#
#              nlp_path language  similarity_threshold  cleanup_threshold  \
# 0    UOP_section_true       EN                  0.65               0.65
# 1               Table       EN                  0.65               0.65
# 2               Table       EN                  0.65               0.65
# 3               Table       ES                  0.65               0.65
# 4               Table       PT                  0.65               0.65
# 5               Table       PT                  0.65               0.65
# 6    UOP_section_true       PT                  0.65               0.65
# 7    UOP_section_true       ES                  0.65               0.65
# 8    UOP_section_true       ES                  0.65               0.65
# 9    UOP_section_true       ES                  0.65               0.65
# 10  UOP_section_false       ES                  0.65               0.65
# 11              Table       ES                  0.65               0.65
# 12              Table       ES                  0.65               0.65
# 13   UOP_section_true       ES                  0.65               0.65
# 14              Table       EN                  0.65               0.65
# 15              Table       EN                  0.65               0.65
# 16   UOP_section_true       EN                  0.65               0.65
# 17   UOP_section_true       EN                  0.65               0.65
# 18   UOP_section_true       EN                  0.65               0.65
# 19              Table       EN                  0.65               0.65
# 20   UOP_section_true       EN                  0.65               0.65
# 21  UOP_section_false       EN                  0.65               0.65
# 22              Table       EN                  0.65               0.65
# 23              Table       EN                  0.65               0.65
# 24  UOP_section_false       EN                  0.65               0.65
# 25   UOP_section_true       EN                  0.65               0.65
# 26  UOP_section_false       EN                  0.65               0.65
# 27  UOP_section_false       EN                  0.65               0.65
# 28  UOP_section_false       EN                  0.65               0.65
# 29              Table       EN                  0.65               0.65
# 30   UOP_section_true       EN                  0.65               0.65
# 31              Table       EN                  0.65               0.65
# 32              Table       EN                  0.65               0.65
# 33   UOP_section_true       EN                  0.65               0.65
# 34              Table       EN                  0.65               0.65
#
#     ES_0_percent  ES_100_percent  ES_partial  number_of_cats
# 0          False           False        True               3
# 1          False           False        True               8
# 2          False            True       False               1
# 3          False            True       False               1
# 4          False           False        True               2
# 5          False           False        True               2
# 6          False           False        True               9
# 7          False           False        True              10
# 8           True           False       False               5
# 9          False           False        True               9
# 10         False           False        True              10
# 11         False           False        True               2
# 12         False            True       False               1
# 13         False           False        True              10
# 14          True           False       False               2
# 15         False           False        True               2
# 16         False           False        True               4
# 17         False           False        True               4
# 18         False           False        True              10
# 19         False           False        True               3
# 20         False           False        True               3
# 21         False           False        True               7
# 22         False           False        True               4
# 23         False           False        True               6
# 24         False           False        True               5
# 25         False           False        True               4
# 26         False           False        True               7
# 27         False           False        True               7
# 28         False           False        True               7
# 29         False           False        True               2
# 30         False            True       False               1
# 31         False           False        True               2
# 32         False           False        True               2
# 33         False           False        True              10
# 34         False           False        True               3
